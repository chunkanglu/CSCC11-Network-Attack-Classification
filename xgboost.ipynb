# %%
import random

import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, roc_auc_score, classification_report

# %%
RANDOM_SEED = 42
DATA_PATH = "data/"
DATA_FILE = "processed_traffic.parquet"

# %%
data = pd.read_parquet(DATA_PATH + DATA_FILE)
data_train, data_test = train_test_split(data, test_size=0.1, random_state=RANDOM_SEED)
data_train.shape, data_test.shape
# Out:
# ((55960, 49), (6218, 49))

# %%
X_train, y_train = data_train.drop(columns=["Attack Name", "Label"]), data_train["Label"]
X_test, y_test = data_test.drop(columns=["Attack Name", "Label"]), data_test["Label"]
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

# %%
param = {
    'objective': 'binary:logistic',
    'eval_metric': ['auc', 'error', 'logloss'],
    'device': 'cuda',
    'verbosity': 1,
}
evallist = [(dtrain, 'train'), (dtest, 'eval')]
model = xgb.train(param, dtrain, num_boost_round=200, evals=evallist, early_stopping_rounds=10)
# Out:
# [0]	train-auc:0.91241	train-error:0.11951	train-logloss:0.53299	eval-auc:0.90914	eval-error:0.12496	eval-logloss:0.53532
# [1]	train-auc:0.92778	train-error:0.11825	train-logloss:0.44553	eval-auc:0.92447	eval-error:0.12432	eval-logloss:0.44947
# [2]	train-auc:0.94719	train-error:0.10602	train-logloss:0.38447	eval-auc:0.94572	eval-error:0.10856	eval-logloss:0.38825
# [3]	train-auc:0.94968	train-error:0.10593	train-logloss:0.34632	eval-auc:0.94760	eval-error:0.10839	eval-logloss:0.35063
# [4]	train-auc:0.95274	train-error:0.10724	train-logloss:0.31868	eval-auc:0.95006	eval-error:0.11129	eval-logloss:0.32444
# [5]	train-auc:0.96224	train-error:0.10340	train-logloss:0.28885	eval-auc:0.95970	eval-error:0.10984	eval-logloss:0.29590
# [6]	train-auc:0.96541	train-error:0.09971	train-logloss:0.27143	eval-auc:0.96150	eval-error:0.10486	eval-logloss:0.27922
# [7]	train-auc:0.97269	train-error:0.07766	train-logloss:0.24622	eval-auc:0.97033	eval-error:0.08154	eval-logloss:0.25317
# [8]	train-auc:0.97941	train-error:0.06987	train-logloss:0.22399	eval-auc:0.97839	eval-error:0.07285	eval-logloss:0.22905
# [9]	train-auc:0.98349	train-error:0.06921	train-logloss:0.20427	eval-auc:0.98337	eval-error:0.07430	eval-logloss:0.20846
# [10]	train-auc:0.98479	train-error:0.06456	train-logloss:0.19540	eval-auc:0.98446	eval-error:0.06803	eval-logloss:0.19931
# [11]	train-auc:0.98743	train-error:0.05940	train-logloss:0.18196	eval-auc:0.98767	eval-error:0.06385	eval-logloss:0.18457
# [12]	train-auc:0.99051	train-error:0.05168	train-logloss:0.16279	eval-auc:0.98995	eval-error:0.05372	eval-logloss:0.16657
# [13]	train-auc:0.99342	train-error:0.03460	train-logloss:0.14063	eval-auc:0.99279	eval-error:0.03602	eval-logloss:0.14317
# [14]	train-auc:0.99422	train-error:0.03066	train-logloss:0.13097	eval-auc:0.99340	eval-error:0.03249	eval-logloss:0.13407
# [15]	train-auc:0.99516	train-error:0.02738	train-logloss:0.11766	eval-auc:0.99420	eval-error:0.02991	eval-logloss:0.12092
# [16]	train-auc:0.99532	train-error:0.02611	train-logloss:0.11332	eval-auc:0.99447	eval-error:0.02798	eval-logloss:0.11608
# [17]	train-auc:0.99668	train-error:0.02346	train-logloss:0.10233	eval-auc:0.99594	eval-error:0.02509	eval-logloss:0.10555
# [18]	train-auc:0.99715	train-error:0.02085	train-logloss:0.09520	eval-auc:0.99630	eval-error:0.02139	eval-logloss:0.09863
# [19]	train-auc:0.99729	train-error:0.02026	train-logloss:0.09244	eval-auc:0.99633	eval-error:0.02123	eval-logloss:0.09629
# [20]	train-auc:0.99760	train-error:0.01971	train-logloss:0.08683	eval-auc:0.99661	eval-error:0.02187	eval-logloss:0.09133
# [21]	train-auc:0.99799	train-error:0.01683	train-logloss:0.07883	eval-auc:0.99702	eval-error:0.01833	eval-logloss:0.08325
# [22]	train-auc:0.99825	train-error:0.01503	train-logloss:0.07384	eval-auc:0.99746	eval-error:0.01592	eval-logloss:0.07797
# [23]	train-auc:0.99852	train-error:0.01451	train-logloss:0.07080	eval-auc:0.99779	eval-error:0.01544	eval-logloss:0.07512
# [24]	train-auc:0.99864	train-error:0.01444	train-logloss:0.06735	eval-auc:0.99788	eval-error:0.01544	eval-logloss:0.07150
# [25]	train-auc:0.99883	train-error:0.01301	train-logloss:0.06261	eval-auc:0.99813	eval-error:0.01431	eval-logloss:0.06686
# [26]	train-auc:0.99896	train-error:0.01169	train-logloss:0.05796	eval-auc:0.99824	eval-error:0.01303	eval-logloss:0.06270
# [27]	train-auc:0.99902	train-error:0.01135	train-logloss:0.05640	eval-auc:0.99837	eval-error:0.01383	eval-logloss:0.06108
# [28]	train-auc:0.99910	train-error:0.01070	train-logloss:0.05404	eval-auc:0.99849	eval-error:0.01287	eval-logloss:0.05888
# [29]	train-auc:0.99916	train-error:0.01038	train-logloss:0.05283	eval-auc:0.99855	eval-error:0.01238	eval-logloss:0.05752
# [30]	train-auc:0.99928	train-error:0.00976	train-logloss:0.05107	eval-auc:0.99860	eval-error:0.01222	eval-logloss:0.05621
# [31]	train-auc:0.99933	train-error:0.00954	train-logloss:0.04940	eval-auc:0.99866	eval-error:0.01254	eval-logloss:0.05459
# [32]	train-auc:0.99937	train-error:0.00924	train-logloss:0.04786	eval-auc:0.99875	eval-error:0.01190	eval-logloss:0.05321
# [33]	train-auc:0.99945	train-error:0.00892	train-logloss:0.04534	eval-auc:0.99887	eval-error:0.01222	eval-logloss:0.05086
# [34]	train-auc:0.99950	train-error:0.00860	train-logloss:0.04345	eval-auc:0.99889	eval-error:0.01254	eval-logloss:0.04946
# [35]	train-auc:0.99954	train-error:0.00826	train-logloss:0.04240	eval-auc:0.99899	eval-error:0.01238	eval-logloss:0.04878
# [36]	train-auc:0.99958	train-error:0.00754	train-logloss:0.04098	eval-auc:0.99896	eval-error:0.01222	eval-logloss:0.04784
# [37]	train-auc:0.99962	train-error:0.00727	train-logloss:0.03935	eval-auc:0.99905	eval-error:0.01174	eval-logloss:0.04659
# [38]	train-auc:0.99963	train-error:0.00717	train-logloss:0.03911	eval-auc:0.99906	eval-error:0.01174	eval-logloss:0.04639
# [39]	train-auc:0.99965	train-error:0.00713	train-logloss:0.03835	eval-auc:0.99909	eval-error:0.01174	eval-logloss:0.04581
# [40]	train-auc:0.99968	train-error:0.00704	train-logloss:0.03663	eval-auc:0.99917	eval-error:0.01190	eval-logloss:0.04405
# [41]	train-auc:0.99970	train-error:0.00679	train-logloss:0.03559	eval-auc:0.99923	eval-error:0.01206	eval-logloss:0.04330
# [42]	train-auc:0.99974	train-error:0.00649	train-logloss:0.03440	eval-auc:0.99932	eval-error:0.01174	eval-logloss:0.04235
# [43]	train-auc:0.99976	train-error:0.00636	train-logloss:0.03338	eval-auc:0.99931	eval-error:0.01158	eval-logloss:0.04166
# [44]	train-auc:0.99978	train-error:0.00613	train-logloss:0.03184	eval-auc:0.99936	eval-error:0.01110	eval-logloss:0.04016
# [45]	train-auc:0.99979	train-error:0.00597	train-logloss:0.03139	eval-auc:0.99937	eval-error:0.01110	eval-logloss:0.03999
# [46]	train-auc:0.99980	train-error:0.00597	train-logloss:0.03086	eval-auc:0.99939	eval-error:0.01126	eval-logloss:0.03949
# [47]	train-auc:0.99981	train-error:0.00590	train-logloss:0.02957	eval-auc:0.99942	eval-error:0.01142	eval-logloss:0.03827
# [48]	train-auc:0.99982	train-error:0.00572	train-logloss:0.02886	eval-auc:0.99945	eval-error:0.01142	eval-logloss:0.03759
# [49]	train-auc:0.99983	train-error:0.00552	train-logloss:0.02853	eval-auc:0.99945	eval-error:0.01094	eval-logloss:0.03737
# [50]	train-auc:0.99984	train-error:0.00525	train-logloss:0.02815	eval-auc:0.99946	eval-error:0.01110	eval-logloss:0.03698
# [51]	train-auc:0.99984	train-error:0.00509	train-logloss:0.02784	eval-auc:0.99946	eval-error:0.01126	eval-logloss:0.03687
# [52]	train-auc:0.99984	train-error:0.00511	train-logloss:0.02734	eval-auc:0.99948	eval-error:0.01126	eval-logloss:0.03637
# [53]	train-auc:0.99985	train-error:0.00493	train-logloss:0.02716	eval-auc:0.99948	eval-error:0.01110	eval-logloss:0.03629
# [54]	train-auc:0.99985	train-error:0.00493	train-logloss:0.02688	eval-auc:0.99949	eval-error:0.01110	eval-logloss:0.03613
# [55]	train-auc:0.99985	train-error:0.00493	train-logloss:0.02679	eval-auc:0.99948	eval-error:0.01110	eval-logloss:0.03617
# [56]	train-auc:0.99986	train-error:0.00484	train-logloss:0.02595	eval-auc:0.99950	eval-error:0.01110	eval-logloss:0.03548
# [57]	train-auc:0.99986	train-error:0.00481	train-logloss:0.02532	eval-auc:0.99951	eval-error:0.01094	eval-logloss:0.03487
# [58]	train-auc:0.99987	train-error:0.00463	train-logloss:0.02499	eval-auc:0.99951	eval-error:0.01094	eval-logloss:0.03485
# [59]	train-auc:0.99988	train-error:0.00440	train-logloss:0.02435	eval-auc:0.99953	eval-error:0.01094	eval-logloss:0.03411
# [60]	train-auc:0.99989	train-error:0.00422	train-logloss:0.02368	eval-auc:0.99954	eval-error:0.01061	eval-logloss:0.03368
# [61]	train-auc:0.99990	train-error:0.00406	train-logloss:0.02337	eval-auc:0.99955	eval-error:0.01013	eval-logloss:0.03343
# [62]	train-auc:0.99990	train-error:0.00397	train-logloss:0.02314	eval-auc:0.99956	eval-error:0.01013	eval-logloss:0.03319
# [63]	train-auc:0.99991	train-error:0.00390	train-logloss:0.02296	eval-auc:0.99958	eval-error:0.00997	eval-logloss:0.03295
# [64]	train-auc:0.99991	train-error:0.00381	train-logloss:0.02246	eval-auc:0.99959	eval-error:0.00997	eval-logloss:0.03247
# [65]	train-auc:0.99991	train-error:0.00372	train-logloss:0.02186	eval-auc:0.99961	eval-error:0.00981	eval-logloss:0.03188
# [66]	train-auc:0.99992	train-error:0.00357	train-logloss:0.02135	eval-auc:0.99961	eval-error:0.00981	eval-logloss:0.03137
# [67]	train-auc:0.99992	train-error:0.00350	train-logloss:0.02076	eval-auc:0.99962	eval-error:0.00981	eval-logloss:0.03083
# [68]	train-auc:0.99992	train-error:0.00340	train-logloss:0.02055	eval-auc:0.99963	eval-error:0.00981	eval-logloss:0.03058
# [69]	train-auc:0.99993	train-error:0.00343	train-logloss:0.02008	eval-auc:0.99963	eval-error:0.00965	eval-logloss:0.03018
# [70]	train-auc:0.99993	train-error:0.00334	train-logloss:0.01972	eval-auc:0.99964	eval-error:0.00965	eval-logloss:0.02983
# [71]	train-auc:0.99993	train-error:0.00334	train-logloss:0.01955	eval-auc:0.99964	eval-error:0.00965	eval-logloss:0.02970
# [72]	train-auc:0.99993	train-error:0.00322	train-logloss:0.01908	eval-auc:0.99964	eval-error:0.00965	eval-logloss:0.02923
# [73]	train-auc:0.99994	train-error:0.00323	train-logloss:0.01820	eval-auc:0.99965	eval-error:0.00997	eval-logloss:0.02839
# [74]	train-auc:0.99995	train-error:0.00302	train-logloss:0.01771	eval-auc:0.99967	eval-error:0.00981	eval-logloss:0.02796
# [75]	train-auc:0.99995	train-error:0.00302	train-logloss:0.01762	eval-auc:0.99967	eval-error:0.00981	eval-logloss:0.02788
# [76]	train-auc:0.99995	train-error:0.00297	train-logloss:0.01726	eval-auc:0.99967	eval-error:0.00981	eval-logloss:0.02757
# [77]	train-auc:0.99995	train-error:0.00284	train-logloss:0.01676	eval-auc:0.99967	eval-error:0.00933	eval-logloss:0.02741
# [78]	train-auc:0.99995	train-error:0.00282	train-logloss:0.01663	eval-auc:0.99967	eval-error:0.00949	eval-logloss:0.02738
# [79]	train-auc:0.99996	train-error:0.00279	train-logloss:0.01619	eval-auc:0.99967	eval-error:0.00949	eval-logloss:0.02710
# [80]	train-auc:0.99996	train-error:0.00279	train-logloss:0.01611	eval-auc:0.99967	eval-error:0.00949	eval-logloss:0.02710
# [81]	train-auc:0.99996	train-error:0.00275	train-logloss:0.01594	eval-auc:0.99968	eval-error:0.00965	eval-logloss:0.02680
# [82]	train-auc:0.99996	train-error:0.00266	train-logloss:0.01572	eval-auc:0.99969	eval-error:0.00965	eval-logloss:0.02665
# [83]	train-auc:0.99996	train-error:0.00248	train-logloss:0.01543	eval-auc:0.99968	eval-error:0.00949	eval-logloss:0.02654
# [84]	train-auc:0.99997	train-error:0.00238	train-logloss:0.01518	eval-auc:0.99969	eval-error:0.00933	eval-logloss:0.02640
# [85]	train-auc:0.99997	train-error:0.00231	train-logloss:0.01490	eval-auc:0.99969	eval-error:0.00933	eval-logloss:0.02625
# [86]	train-auc:0.99997	train-error:0.00231	train-logloss:0.01473	eval-auc:0.99969	eval-error:0.00901	eval-logloss:0.02617
# [87]	train-auc:0.99997	train-error:0.00227	train-logloss:0.01460	eval-auc:0.99970	eval-error:0.00885	eval-logloss:0.02599
# [88]	train-auc:0.99997	train-error:0.00227	train-logloss:0.01456	eval-auc:0.99970	eval-error:0.00885	eval-logloss:0.02599
# [89]	train-auc:0.99997	train-error:0.00222	train-logloss:0.01448	eval-auc:0.99970	eval-error:0.00901	eval-logloss:0.02597
# [90]	train-auc:0.99997	train-error:0.00220	train-logloss:0.01434	eval-auc:0.99970	eval-error:0.00885	eval-logloss:0.02596
# [91]	train-auc:0.99997	train-error:0.00218	train-logloss:0.01426	eval-auc:0.99970	eval-error:0.00885	eval-logloss:0.02584
# [92]	train-auc:0.99997	train-error:0.00218	train-logloss:0.01416	eval-auc:0.99970	eval-error:0.00885	eval-logloss:0.02586
# [93]	train-auc:0.99998	train-error:0.00214	train-logloss:0.01398	eval-auc:0.99970	eval-error:0.00901	eval-logloss:0.02591
# [94]	train-auc:0.99998	train-error:0.00211	train-logloss:0.01387	eval-auc:0.99970	eval-error:0.00901	eval-logloss:0.02591
# [95]	train-auc:0.99998	train-error:0.00209	train-logloss:0.01338	eval-auc:0.99970	eval-error:0.00885	eval-logloss:0.02547
# [96]	train-auc:0.99998	train-error:0.00200	train-logloss:0.01315	eval-auc:0.99971	eval-error:0.00885	eval-logloss:0.02528
# [97]	train-auc:0.99998	train-error:0.00193	train-logloss:0.01274	eval-auc:0.99971	eval-error:0.00885	eval-logloss:0.02493
# [98]	train-auc:0.99998	train-error:0.00188	train-logloss:0.01247	eval-auc:0.99971	eval-error:0.00901	eval-logloss:0.02472
# [99]	train-auc:0.99998	train-error:0.00186	train-logloss:0.01237	eval-auc:0.99972	eval-error:0.00901	eval-logloss:0.02458
# [100]	train-auc:0.99998	train-error:0.00177	train-logloss:0.01228	eval-auc:0.99972	eval-error:0.00885	eval-logloss:0.02458
# [101]	train-auc:0.99998	train-error:0.00175	train-logloss:0.01215	eval-auc:0.99972	eval-error:0.00885	eval-logloss:0.02443
# [102]	train-auc:0.99998	train-error:0.00173	train-logloss:0.01211	eval-auc:0.99972	eval-error:0.00868	eval-logloss:0.02437
# [103]	train-auc:0.99998	train-error:0.00161	train-logloss:0.01190	eval-auc:0.99972	eval-error:0.00885	eval-logloss:0.02413
# [104]	train-auc:0.99998	train-error:0.00159	train-logloss:0.01166	eval-auc:0.99972	eval-error:0.00901	eval-logloss:0.02393
# [105]	train-auc:0.99998	train-error:0.00154	train-logloss:0.01162	eval-auc:0.99972	eval-error:0.00901	eval-logloss:0.02396
# [106]	train-auc:0.99998	train-error:0.00152	train-logloss:0.01155	eval-auc:0.99973	eval-error:0.00901	eval-logloss:0.02390
# [107]	train-auc:0.99998	train-error:0.00152	train-logloss:0.01150	eval-auc:0.99973	eval-error:0.00901	eval-logloss:0.02389
# [108]	train-auc:0.99998	train-error:0.00143	train-logloss:0.01130	eval-auc:0.99973	eval-error:0.00901	eval-logloss:0.02369
# [109]	train-auc:0.99998	train-error:0.00143	train-logloss:0.01114	eval-auc:0.99973	eval-error:0.00917	eval-logloss:0.02354
# [110]	train-auc:0.99999	train-error:0.00139	train-logloss:0.01102	eval-auc:0.99973	eval-error:0.00933	eval-logloss:0.02358
# [111]	train-auc:0.99999	train-error:0.00139	train-logloss:0.01098	eval-auc:0.99973	eval-error:0.00933	eval-logloss:0.02356
# [112]	train-auc:0.99999	train-error:0.00132	train-logloss:0.01089	eval-auc:0.99973	eval-error:0.00917	eval-logloss:0.02349
# [113]	train-auc:0.99999	train-error:0.00130	train-logloss:0.01064	eval-auc:0.99974	eval-error:0.00901	eval-logloss:0.02315
# [114]	train-auc:0.99999	train-error:0.00134	train-logloss:0.01048	eval-auc:0.99974	eval-error:0.00885	eval-logloss:0.02314
# [115]	train-auc:0.99999	train-error:0.00134	train-logloss:0.01023	eval-auc:0.99974	eval-error:0.00868	eval-logloss:0.02289
# [116]	train-auc:0.99999	train-error:0.00134	train-logloss:0.01008	eval-auc:0.99974	eval-error:0.00885	eval-logloss:0.02273
# [117]	train-auc:0.99999	train-error:0.00127	train-logloss:0.00987	eval-auc:0.99974	eval-error:0.00852	eval-logloss:0.02253
# [118]	train-auc:0.99999	train-error:0.00125	train-logloss:0.00980	eval-auc:0.99974	eval-error:0.00868	eval-logloss:0.02254
# [119]	train-auc:0.99999	train-error:0.00120	train-logloss:0.00959	eval-auc:0.99974	eval-error:0.00852	eval-logloss:0.02233
# [120]	train-auc:0.99999	train-error:0.00118	train-logloss:0.00945	eval-auc:0.99975	eval-error:0.00868	eval-logloss:0.02220
# [121]	train-auc:0.99999	train-error:0.00111	train-logloss:0.00935	eval-auc:0.99975	eval-error:0.00868	eval-logloss:0.02219
# [122]	train-auc:0.99999	train-error:0.00111	train-logloss:0.00925	eval-auc:0.99974	eval-error:0.00901	eval-logloss:0.02217
# [123]	train-auc:0.99999	train-error:0.00111	train-logloss:0.00914	eval-auc:0.99974	eval-error:0.00885	eval-logloss:0.02224
# [124]	train-auc:0.99999	train-error:0.00102	train-logloss:0.00900	eval-auc:0.99975	eval-error:0.00836	eval-logloss:0.02207
# [125]	train-auc:0.99999	train-error:0.00100	train-logloss:0.00886	eval-auc:0.99975	eval-error:0.00836	eval-logloss:0.02200
# [126]	train-auc:0.99999	train-error:0.00098	train-logloss:0.00875	eval-auc:0.99975	eval-error:0.00836	eval-logloss:0.02187
# [127]	train-auc:0.99999	train-error:0.00095	train-logloss:0.00863	eval-auc:0.99975	eval-error:0.00820	eval-logloss:0.02170
# [128]	train-auc:0.99999	train-error:0.00091	train-logloss:0.00857	eval-auc:0.99975	eval-error:0.00820	eval-logloss:0.02171
# [129]	train-auc:0.99999	train-error:0.00088	train-logloss:0.00847	eval-auc:0.99975	eval-error:0.00804	eval-logloss:0.02161
# [130]	train-auc:0.99999	train-error:0.00088	train-logloss:0.00834	eval-auc:0.99976	eval-error:0.00820	eval-logloss:0.02136
# [131]	train-auc:0.99999	train-error:0.00088	train-logloss:0.00826	eval-auc:0.99976	eval-error:0.00836	eval-logloss:0.02131
# [132]	train-auc:0.99999	train-error:0.00086	train-logloss:0.00820	eval-auc:0.99976	eval-error:0.00820	eval-logloss:0.02128
# [133]	train-auc:0.99999	train-error:0.00084	train-logloss:0.00814	eval-auc:0.99976	eval-error:0.00804	eval-logloss:0.02121
# [134]	train-auc:0.99999	train-error:0.00080	train-logloss:0.00802	eval-auc:0.99976	eval-error:0.00820	eval-logloss:0.02107
# [135]	train-auc:0.99999	train-error:0.00080	train-logloss:0.00789	eval-auc:0.99976	eval-error:0.00836	eval-logloss:0.02097
# [136]	train-auc:0.99999	train-error:0.00079	train-logloss:0.00780	eval-auc:0.99977	eval-error:0.00804	eval-logloss:0.02092
# [137]	train-auc:0.99999	train-error:0.00079	train-logloss:0.00775	eval-auc:0.99977	eval-error:0.00820	eval-logloss:0.02101
# [138]	train-auc:0.99999	train-error:0.00077	train-logloss:0.00766	eval-auc:0.99977	eval-error:0.00804	eval-logloss:0.02092
# [139]	train-auc:0.99999	train-error:0.00077	train-logloss:0.00757	eval-auc:0.99977	eval-error:0.00804	eval-logloss:0.02069
# [140]	train-auc:1.00000	train-error:0.00073	train-logloss:0.00751	eval-auc:0.99977	eval-error:0.00788	eval-logloss:0.02062
# [141]	train-auc:1.00000	train-error:0.00073	train-logloss:0.00746	eval-auc:0.99977	eval-error:0.00788	eval-logloss:0.02062
# [142]	train-auc:1.00000	train-error:0.00071	train-logloss:0.00736	eval-auc:0.99978	eval-error:0.00772	eval-logloss:0.02055
# [143]	train-auc:1.00000	train-error:0.00070	train-logloss:0.00717	eval-auc:0.99978	eval-error:0.00788	eval-logloss:0.02042
# [144]	train-auc:1.00000	train-error:0.00066	train-logloss:0.00710	eval-auc:0.99978	eval-error:0.00820	eval-logloss:0.02035
# [145]	train-auc:1.00000	train-error:0.00061	train-logloss:0.00700	eval-auc:0.99978	eval-error:0.00788	eval-logloss:0.02023
# [146]	train-auc:1.00000	train-error:0.00055	train-logloss:0.00690	eval-auc:0.99978	eval-error:0.00788	eval-logloss:0.02025
# [147]	train-auc:1.00000	train-error:0.00055	train-logloss:0.00679	eval-auc:0.99978	eval-error:0.00772	eval-logloss:0.02025
# [148]	train-auc:1.00000	train-error:0.00057	train-logloss:0.00673	eval-auc:0.99979	eval-error:0.00772	eval-logloss:0.02013
# [149]	train-auc:1.00000	train-error:0.00057	train-logloss:0.00668	eval-auc:0.99979	eval-error:0.00756	eval-logloss:0.02002
# [150]	train-auc:1.00000	train-error:0.00057	train-logloss:0.00664	eval-auc:0.99979	eval-error:0.00756	eval-logloss:0.01991
# [151]	train-auc:1.00000	train-error:0.00059	train-logloss:0.00661	eval-auc:0.99979	eval-error:0.00772	eval-logloss:0.01999
# [152]	train-auc:1.00000	train-error:0.00057	train-logloss:0.00655	eval-auc:0.99979	eval-error:0.00772	eval-logloss:0.01993
# [153]	train-auc:1.00000	train-error:0.00057	train-logloss:0.00652	eval-auc:0.99979	eval-error:0.00788	eval-logloss:0.01988
# [154]	train-auc:1.00000	train-error:0.00059	train-logloss:0.00644	eval-auc:0.99980	eval-error:0.00756	eval-logloss:0.01969
# [155]	train-auc:1.00000	train-error:0.00059	train-logloss:0.00640	eval-auc:0.99980	eval-error:0.00756	eval-logloss:0.01970
# [156]	train-auc:1.00000	train-error:0.00057	train-logloss:0.00634	eval-auc:0.99979	eval-error:0.00740	eval-logloss:0.01971
# [157]	train-auc:1.00000	train-error:0.00057	train-logloss:0.00626	eval-auc:0.99980	eval-error:0.00740	eval-logloss:0.01960
# [158]	train-auc:1.00000	train-error:0.00055	train-logloss:0.00618	eval-auc:0.99980	eval-error:0.00740	eval-logloss:0.01953
# [159]	train-auc:1.00000	train-error:0.00054	train-logloss:0.00609	eval-auc:0.99980	eval-error:0.00740	eval-logloss:0.01947
# [160]	train-auc:1.00000	train-error:0.00054	train-logloss:0.00600	eval-auc:0.99980	eval-error:0.00724	eval-logloss:0.01937
# [161]	train-auc:1.00000	train-error:0.00050	train-logloss:0.00595	eval-auc:0.99980	eval-error:0.00740	eval-logloss:0.01936
# [162]	train-auc:1.00000	train-error:0.00050	train-logloss:0.00591	eval-auc:0.99980	eval-error:0.00740	eval-logloss:0.01935
# [163]	train-auc:1.00000	train-error:0.00048	train-logloss:0.00583	eval-auc:0.99980	eval-error:0.00740	eval-logloss:0.01929
# [164]	train-auc:1.00000	train-error:0.00048	train-logloss:0.00578	eval-auc:0.99980	eval-error:0.00740	eval-logloss:0.01925
# [165]	train-auc:1.00000	train-error:0.00048	train-logloss:0.00575	eval-auc:0.99980	eval-error:0.00740	eval-logloss:0.01926
# [166]	train-auc:1.00000	train-error:0.00048	train-logloss:0.00568	eval-auc:0.99980	eval-error:0.00756	eval-logloss:0.01917
# [167]	train-auc:1.00000	train-error:0.00048	train-logloss:0.00562	eval-auc:0.99980	eval-error:0.00756	eval-logloss:0.01917
# [168]	train-auc:1.00000	train-error:0.00046	train-logloss:0.00558	eval-auc:0.99980	eval-error:0.00740	eval-logloss:0.01919
# [169]	train-auc:1.00000	train-error:0.00046	train-logloss:0.00555	eval-auc:0.99980	eval-error:0.00708	eval-logloss:0.01912
# [170]	train-auc:1.00000	train-error:0.00043	train-logloss:0.00550	eval-auc:0.99980	eval-error:0.00708	eval-logloss:0.01907
# [171]	train-auc:1.00000	train-error:0.00043	train-logloss:0.00546	eval-auc:0.99980	eval-error:0.00740	eval-logloss:0.01898
# [172]	train-auc:1.00000	train-error:0.00043	train-logloss:0.00543	eval-auc:0.99980	eval-error:0.00772	eval-logloss:0.01893
# [173]	train-auc:1.00000	train-error:0.00043	train-logloss:0.00541	eval-auc:0.99980	eval-error:0.00772	eval-logloss:0.01892
# [174]	train-auc:1.00000	train-error:0.00043	train-logloss:0.00536	eval-auc:0.99980	eval-error:0.00772	eval-logloss:0.01887
# [175]	train-auc:1.00000	train-error:0.00043	train-logloss:0.00531	eval-auc:0.99980	eval-error:0.00772	eval-logloss:0.01885
# [176]	train-auc:1.00000	train-error:0.00043	train-logloss:0.00526	eval-auc:0.99980	eval-error:0.00788	eval-logloss:0.01881
# [177]	train-auc:1.00000	train-error:0.00041	train-logloss:0.00521	eval-auc:0.99981	eval-error:0.00772	eval-logloss:0.01878
# [178]	train-auc:1.00000	train-error:0.00039	train-logloss:0.00519	eval-auc:0.99981	eval-error:0.00772	eval-logloss:0.01882
# [179]	train-auc:1.00000	train-error:0.00039	train-logloss:0.00517	eval-auc:0.99981	eval-error:0.00772	eval-logloss:0.01875
# [180]	train-auc:1.00000	train-error:0.00041	train-logloss:0.00514	eval-auc:0.99981	eval-error:0.00772	eval-logloss:0.01870
# [181]	train-auc:1.00000	train-error:0.00045	train-logloss:0.00511	eval-auc:0.99981	eval-error:0.00772	eval-logloss:0.01871
# [182]	train-auc:1.00000	train-error:0.00045	train-logloss:0.00509	eval-auc:0.99981	eval-error:0.00788	eval-logloss:0.01873
# [183]	train-auc:1.00000	train-error:0.00045	train-logloss:0.00508	eval-auc:0.99981	eval-error:0.00788	eval-logloss:0.01874
# [184]	train-auc:1.00000	train-error:0.00045	train-logloss:0.00505	eval-auc:0.99981	eval-error:0.00772	eval-logloss:0.01878
# [185]	train-auc:1.00000	train-error:0.00043	train-logloss:0.00504	eval-auc:0.99980	eval-error:0.00772	eval-logloss:0.01880
# [186]	train-auc:1.00000	train-error:0.00041	train-logloss:0.00501	eval-auc:0.99980	eval-error:0.00788	eval-logloss:0.01877
# [187]	train-auc:1.00000	train-error:0.00039	train-logloss:0.00498	eval-auc:0.99981	eval-error:0.00788	eval-logloss:0.01869
# [188]	train-auc:1.00000	train-error:0.00036	train-logloss:0.00492	eval-auc:0.99981	eval-error:0.00756	eval-logloss:0.01863
# [189]	train-auc:1.00000	train-error:0.00032	train-logloss:0.00488	eval-auc:0.99981	eval-error:0.00756	eval-logloss:0.01865
# [190]	train-auc:1.00000	train-error:0.00032	train-logloss:0.00487	eval-auc:0.99981	eval-error:0.00756	eval-logloss:0.01859
# [191]	train-auc:1.00000	train-error:0.00032	train-logloss:0.00480	eval-auc:0.99981	eval-error:0.00740	eval-logloss:0.01850
# [192]	train-auc:1.00000	train-error:0.00034	train-logloss:0.00475	eval-auc:0.99981	eval-error:0.00756	eval-logloss:0.01850
# [193]	train-auc:1.00000	train-error:0.00034	train-logloss:0.00469	eval-auc:0.99981	eval-error:0.00708	eval-logloss:0.01839
# [194]	train-auc:1.00000	train-error:0.00032	train-logloss:0.00465	eval-auc:0.99981	eval-error:0.00692	eval-logloss:0.01836
# [195]	train-auc:1.00000	train-error:0.00030	train-logloss:0.00462	eval-auc:0.99981	eval-error:0.00692	eval-logloss:0.01834
# [196]	train-auc:1.00000	train-error:0.00030	train-logloss:0.00458	eval-auc:0.99981	eval-error:0.00724	eval-logloss:0.01830
# [197]	train-auc:1.00000	train-error:0.00030	train-logloss:0.00455	eval-auc:0.99981	eval-error:0.00724	eval-logloss:0.01830
# [198]	train-auc:1.00000	train-error:0.00030	train-logloss:0.00450	eval-auc:0.99981	eval-error:0.00724	eval-logloss:0.01838
# [199]	train-auc:1.00000	train-error:0.00030	train-logloss:0.00445	eval-auc:0.99981	eval-error:0.00724	eval-logloss:0.01838

# %%
THRESHOLD = 0.5
preds = model.predict(dtest)
accuracy = accuracy_score(y_test, preds > THRESHOLD)
report = classification_report(y_test, preds > THRESHOLD, digits=4)

print(f"Accuracy: {accuracy:.4f}")
print("Classification Report:")
print(report)
# Out:
# Accuracy: 0.9928
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9927    0.9936    0.9931      3264
#            1     0.9929    0.9919    0.9924      2954
#
#     accuracy                         0.9928      6218
#    macro avg     0.9928    0.9927    0.9927      6218
# weighted avg     0.9928    0.9928    0.9928      6218

# %%
comparison = pd.DataFrame(preds, columns=["Predicted Probability"])
comparison["Predicted Label"] = (comparison["Predicted Probability"] > THRESHOLD).astype(int)
comparison["True Label"] = y_test.values
comparison["Attack Name"] = data_test["Attack Name"].values
comparison
# Out:
#       Predicted Probability  Predicted Label  True Label  \
# 0                  0.000478                0           0
# 1                  0.001047                0           0
# 2                  0.998435                1           1
# 3                  0.001985                0           0
# 4                  0.000728                0           0
# ...                     ...              ...         ...
# 6213               0.999448                1           1
# 6214               0.000053                0           0
# 6215               0.999865                1           1
# 6216               0.000850                0           0
# 6217               0.002038                0           0
#
#                    Attack Name
# 0               Benign Traffic
# 1               Benign Traffic
# 2               MQTT Malformed
# 3               Benign Traffic
# 4               Benign Traffic
# ...                        ...
# 6213           DDoS ICMP Flood
# 6214            Benign Traffic
# 6215  Recon Vulnerability Scan
# 6216            Benign Traffic
# 6217            Benign Traffic
#
# [6218 rows x 4 columns]

# %%
incorrect = comparison[comparison["Predicted Label"] != comparison["True Label"]]
incorrect["Attack Name"].value_counts()
# Out:
# Attack Name
# Benign Traffic       21
# DoS UDP Flood         7
# DDoS UDP Flood        6
# DoS ICMP Flood        5
# DDoS ICMP Flood       3
# MQTT Malformed        2
# MITM ARP Spoofing     1
# Name: count, dtype: int64

# %% [markdown]
# # Hyperparameter Tuning

# %% [markdown]
# Random search CV was essentially used due to the large number of hyperparameters that could be tuned. Only the main ones after searching online as the most influential were tuned. The below did not use sklearn modules and interface in order to utilize gpu.

# %%
base_param = {
    'objective': 'binary:logistic',
    'eval_metric': ['auc', 'error', 'logloss'],
    'device': 'cuda',
    'verbosity': 1,
}
evallist = [(dtrain, 'train'), (dtest, 'eval')]

hyperparameter_grid = {
    "max_depth": [3, 5, 7, 9, 11, 13],
    "min_child_weight":[1, 2, 3, 4, 5, 6],
    "subsample":[0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
    "colsample_bytree": [0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
    "eta": [0.01, 0.03, 0.05, 0.1],
}

tested_params = set()
def sample_hyperparameters(grid: dict) -> dict[str, float | int]:
    params = {}
    for key, values in grid.items():
        params[key] = random.choice(values)
    return params

n_iters = 30

best_auc = 0.0
best_iter = -1
best_params = None

for i in range(n_iters):
    sampled_params = sample_hyperparameters(hyperparameter_grid)
    while frozenset(sampled_params.items()) in tested_params:
        sampled_params = sample_hyperparameters(hyperparameter_grid)

    tested_params.add(frozenset(sampled_params.items()))
    param = base_param.copy()
    param.update(sampled_params)
    model = xgb.train(param, dtrain, num_boost_round=2000, evals=evallist, early_stopping_rounds=10, verbose_eval=False)
    preds = model.predict(dtest)
    accuracy = accuracy_score(y_test, preds > THRESHOLD)
    auc = roc_auc_score(y_test, preds)
    precision = precision_score(y_test, preds > THRESHOLD)
    recall = recall_score(y_test, preds > THRESHOLD)
    f1 = f1_score(y_test, preds > THRESHOLD)

    print(f"Iteration {i+1}/{n_iters} - Params: {sampled_params} | Accuracy: {accuracy:.4f} | AUC: {auc:.4f} | Precision: {precision:.4f} | Recall: {recall:.4f} | F1-Score: {f1:.4f}")

    if auc > best_auc:
        best_auc = auc
        best_iter = i + 1
        best_params = sampled_params
        model.save_model(f"XGBModels/model_iter_{i+1}_acc_{accuracy:.4f}_auc_{auc:.4f}.json")

print(f"Best AUC: {best_auc:.4f} with params: {best_params} at iteration {best_iter}")
# Out:
# Iteration 1/30 - Params: {'max_depth': 9, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 1.0, 'eta': 0.05} | Accuracy: 0.9923 | AUC: 0.9998 | Precision: 0.9929 | Recall: 0.9909 | F1-Score: 0.9919
# Iteration 2/30 - Params: {'max_depth': 9, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 1.0, 'eta': 0.01} | Accuracy: 0.9937 | AUC: 0.9998 | Precision: 0.9946 | Recall: 0.9922 | F1-Score: 0.9934
# Iteration 3/30 - Params: {'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.8, 'eta': 0.05} | Accuracy: 0.9916 | AUC: 0.9997 | Precision: 0.9912 | Recall: 0.9912 | F1-Score: 0.9912
# Iteration 4/30 - Params: {'max_depth': 5, 'min_child_weight': 6, 'subsample': 0.8, 'colsample_bytree': 1.0, 'eta': 0.03} | Accuracy: 0.9907 | AUC: 0.9997 | Precision: 0.9918 | Recall: 0.9885 | F1-Score: 0.9902
# Iteration 5/30 - Params: {'max_depth': 7, 'min_child_weight': 4, 'subsample': 0.5, 'colsample_bytree': 1.0, 'eta': 0.03} | Accuracy: 0.9913 | AUC: 0.9998 | Precision: 0.9929 | Recall: 0.9888 | F1-Score: 0.9908
# Iteration 6/30 - Params: {'max_depth': 13, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.7, 'eta': 0.03} | Accuracy: 0.9923 | AUC: 0.9998 | Precision: 0.9925 | Recall: 0.9912 | F1-Score: 0.9919
# Iteration 7/30 - Params: {'max_depth': 11, 'min_child_weight': 1, 'subsample': 0.5, 'colsample_bytree': 0.6, 'eta': 0.01} | Accuracy: 0.9921 | AUC: 0.9998 | Precision: 0.9915 | Recall: 0.9919 | F1-Score: 0.9917
# Iteration 8/30 - Params: {'max_depth': 9, 'min_child_weight': 4, 'subsample': 1.0, 'colsample_bytree': 0.8, 'eta': 0.03} | Accuracy: 0.9924 | AUC: 0.9998 | Precision: 0.9925 | Recall: 0.9915 | F1-Score: 0.9920
# Iteration 9/30 - Params: {'max_depth': 7, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.5, 'eta': 0.03} | Accuracy: 0.9926 | AUC: 0.9997 | Precision: 0.9925 | Recall: 0.9919 | F1-Score: 0.9922
# Iteration 10/30 - Params: {'max_depth': 13, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.6, 'eta': 0.03} | Accuracy: 0.9929 | AUC: 0.9998 | Precision: 0.9936 | Recall: 0.9915 | F1-Score: 0.9925
# Iteration 11/30 - Params: {'max_depth': 9, 'min_child_weight': 6, 'subsample': 0.9, 'colsample_bytree': 0.8, 'eta': 0.01} | Accuracy: 0.9913 | AUC: 0.9997 | Precision: 0.9922 | Recall: 0.9895 | F1-Score: 0.9908
# Iteration 12/30 - Params: {'max_depth': 13, 'min_child_weight': 1, 'subsample': 0.9, 'colsample_bytree': 0.7, 'eta': 0.05} | Accuracy: 0.9937 | AUC: 0.9998 | Precision: 0.9942 | Recall: 0.9926 | F1-Score: 0.9934
# Iteration 13/30 - Params: {'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.5, 'colsample_bytree': 0.7, 'eta': 0.1} | Accuracy: 0.9886 | AUC: 0.9991 | Precision: 0.9891 | Recall: 0.9868 | F1-Score: 0.9880
# Iteration 14/30 - Params: {'max_depth': 9, 'min_child_weight': 4, 'subsample': 1.0, 'colsample_bytree': 0.8, 'eta': 0.1} | Accuracy: 0.9937 | AUC: 0.9998 | Precision: 0.9936 | Recall: 0.9932 | F1-Score: 0.9934
# Iteration 15/30 - Params: {'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.7, 'colsample_bytree': 0.9, 'eta': 0.03} | Accuracy: 0.9860 | AUC: 0.9986 | Precision: 0.9871 | Recall: 0.9834 | F1-Score: 0.9852
# Iteration 16/30 - Params: {'max_depth': 7, 'min_child_weight': 6, 'subsample': 0.9, 'colsample_bytree': 0.8, 'eta': 0.05} | Accuracy: 0.9921 | AUC: 0.9997 | Precision: 0.9929 | Recall: 0.9905 | F1-Score: 0.9917
# Iteration 17/30 - Params: {'max_depth': 13, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.8, 'eta': 0.01} | Accuracy: 0.9915 | AUC: 0.9997 | Precision: 0.9925 | Recall: 0.9895 | F1-Score: 0.9910
# Iteration 18/30 - Params: {'max_depth': 9, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.8, 'eta': 0.03} | Accuracy: 0.9934 | AUC: 0.9998 | Precision: 0.9936 | Recall: 0.9926 | F1-Score: 0.9931
# Iteration 19/30 - Params: {'max_depth': 13, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'eta': 0.03} | Accuracy: 0.9934 | AUC: 0.9998 | Precision: 0.9939 | Recall: 0.9922 | F1-Score: 0.9931
# Iteration 20/30 - Params: {'max_depth': 7, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'eta': 0.03} | Accuracy: 0.9931 | AUC: 0.9998 | Precision: 0.9932 | Recall: 0.9922 | F1-Score: 0.9927
# Iteration 21/30 - Params: {'max_depth': 11, 'min_child_weight': 3, 'subsample': 0.7, 'colsample_bytree': 0.7, 'eta': 0.01} | Accuracy: 0.9920 | AUC: 0.9998 | Precision: 0.9922 | Recall: 0.9909 | F1-Score: 0.9915
# Iteration 22/30 - Params: {'max_depth': 7, 'min_child_weight': 3, 'subsample': 0.7, 'colsample_bytree': 0.6, 'eta': 0.05} | Accuracy: 0.9932 | AUC: 0.9998 | Precision: 0.9932 | Recall: 0.9926 | F1-Score: 0.9929
# Iteration 23/30 - Params: {'max_depth': 7, 'min_child_weight': 2, 'subsample': 0.5, 'colsample_bytree': 0.5, 'eta': 0.05} | Accuracy: 0.9907 | AUC: 0.9996 | Precision: 0.9915 | Recall: 0.9888 | F1-Score: 0.9902
# Iteration 24/30 - Params: {'max_depth': 13, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.9, 'eta': 0.01} | Accuracy: 0.9916 | AUC: 0.9998 | Precision: 0.9929 | Recall: 0.9895 | F1-Score: 0.9912
# Iteration 25/30 - Params: {'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.5, 'colsample_bytree': 0.7, 'eta': 0.05} | Accuracy: 0.9907 | AUC: 0.9996 | Precision: 0.9922 | Recall: 0.9882 | F1-Score: 0.9902
# Iteration 26/30 - Params: {'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.9, 'colsample_bytree': 0.7, 'eta': 0.1} | Accuracy: 0.9883 | AUC: 0.9993 | Precision: 0.9878 | Recall: 0.9875 | F1-Score: 0.9876
# Iteration 27/30 - Params: {'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.8, 'eta': 0.03} | Accuracy: 0.9847 | AUC: 0.9985 | Precision: 0.9851 | Recall: 0.9827 | F1-Score: 0.9839
# Iteration 28/30 - Params: {'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.6, 'colsample_bytree': 0.8, 'eta': 0.01} | Accuracy: 0.9873 | AUC: 0.9988 | Precision: 0.9878 | Recall: 0.9854 | F1-Score: 0.9866
# Iteration 29/30 - Params: {'max_depth': 13, 'min_child_weight': 2, 'subsample': 0.8, 'colsample_bytree': 0.5, 'eta': 0.01} | Accuracy: 0.9929 | AUC: 0.9998 | Precision: 0.9919 | Recall: 0.9932 | F1-Score: 0.9926
# Iteration 30/30 - Params: {'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.7, 'colsample_bytree': 0.9, 'eta': 0.05} | Accuracy: 0.9910 | AUC: 0.9997 | Precision: 0.9915 | Recall: 0.9895 | F1-Score: 0.9905
# Best AUC: 0.9998 with params: {'max_depth': 13, 'min_child_weight': 1, 'subsample': 0.9, 'colsample_bytree': 0.7, 'eta': 0.05} at iteration 12

# %%
best_model = xgb.Booster(model_file="XGBModels/model_iter_12_acc_0.9937_auc_0.9998.json")

# %%
preds = best_model.predict(dtest)
print(classification_report(y_test, preds > THRESHOLD, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9933    0.9948    0.9940      3264
#            1     0.9942    0.9926    0.9934      2954
#
#     accuracy                         0.9937      6218
#    macro avg     0.9938    0.9937    0.9937      6218
# weighted avg     0.9937    0.9937    0.9937      6218

# %%
# See performance at different thresholds
for threshold in [0.2, 0.4, 0.5, 0.6, 0.8]:
    print(f"Threshold: {threshold}")
    print(classification_report(y_test, preds > threshold, digits=4))
# Out:
# Threshold: 0.2
#               precision    recall  f1-score   support
#
#            0     0.9972    0.9862    0.9917      3264
#            1     0.9849    0.9970    0.9909      2954
#
#     accuracy                         0.9913      6218
#    macro avg     0.9911    0.9916    0.9913      6218
# weighted avg     0.9914    0.9913    0.9913      6218
#
# Threshold: 0.4
#               precision    recall  f1-score   support
#
#            0     0.9948    0.9930    0.9939      3264
#            1     0.9922    0.9942    0.9932      2954
#
#     accuracy                         0.9936      6218
#    macro avg     0.9935    0.9936    0.9936      6218
# weighted avg     0.9936    0.9936    0.9936      6218
#
# Threshold: 0.5
#               precision    recall  f1-score   support
#
#            0     0.9933    0.9948    0.9940      3264
#            1     0.9942    0.9926    0.9934      2954
#
#     accuracy                         0.9937      6218
#    macro avg     0.9938    0.9937    0.9937      6218
# weighted avg     0.9937    0.9937    0.9937      6218
#
# Threshold: 0.6
#               precision    recall  f1-score   support
#
#            0     0.9927    0.9954    0.9940      3264
#            1     0.9949    0.9919    0.9934      2954
#
#     accuracy                         0.9937      6218
#    macro avg     0.9938    0.9936    0.9937      6218
# weighted avg     0.9937    0.9937    0.9937      6218
#
# Threshold: 0.8
#               precision    recall  f1-score   support
#
#            0     0.9873    0.9982    0.9927      3264
#            1     0.9979    0.9858    0.9918      2954
#
#     accuracy                         0.9923      6218
#    macro avg     0.9926    0.9920    0.9923      6218
# weighted avg     0.9923    0.9923    0.9923      6218

# %% [markdown]
# Doesn't seem like there's a big difference for using different thresholds. 0.5 seems to give the best balance between accuracy, precision, recall, and f1-score.
