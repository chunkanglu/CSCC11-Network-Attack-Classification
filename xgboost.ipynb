# %%
import random

import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, roc_auc_score, classification_report
from sklearn.inspection import permutation_importance

# %%
RANDOM_SEED = 42
DATA_PATH = "data/"
DATA_FILE = "processed_traffic.parquet"

# %%
data = pd.read_parquet(DATA_PATH + DATA_FILE)
data_train, data_test = train_test_split(data, test_size=0.2, random_state=RANDOM_SEED)
data_train.shape, data_test.shape
# Out:
# ((49742, 49), (12436, 49))

# %%
X_train, y_train = data_train.drop(columns=["Attack Name", "Label"]), data_train["Label"]
X_test, y_test = data_test.drop(columns=["Attack Name", "Label"]), data_test["Label"]
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

# %% [markdown]
# # Initial Train

# %%
param = {
    'objective': 'binary:logistic',
    'eval_metric': ['auc', 'error', 'logloss'],
    'device': 'cuda',
    'verbosity': 1,
}
evallist = [(dtrain, 'train'), (dtest, 'eval')]
model = xgb.train(param, dtrain, num_boost_round=200, evals=evallist, early_stopping_rounds=10)
# Out:
# [0]	train-auc:0.91179	train-error:0.11879	train-logloss:0.53257	eval-auc:0.91143	eval-error:0.12005	eval-logloss:0.53272
# [1]	train-auc:0.92624	train-error:0.11686	train-logloss:0.44519	eval-auc:0.92671	eval-error:0.11740	eval-logloss:0.44535
# [2]	train-auc:0.94804	train-error:0.10792	train-logloss:0.38432	eval-auc:0.94814	eval-error:0.10743	eval-logloss:0.38486
# [3]	train-auc:0.94863	train-error:0.10758	train-logloss:0.34486	eval-auc:0.94819	eval-error:0.10815	eval-logloss:0.34540
# [4]	train-auc:0.95436	train-error:0.10390	train-logloss:0.31308	eval-auc:0.95407	eval-error:0.10550	eval-logloss:0.31437
# [5]	train-auc:0.96189	train-error:0.09778	train-logloss:0.28515	eval-auc:0.96221	eval-error:0.10108	eval-logloss:0.28607
# [6]	train-auc:0.97414	train-error:0.08303	train-logloss:0.25250	eval-auc:0.97358	eval-error:0.08709	eval-logloss:0.25455
# [7]	train-auc:0.97664	train-error:0.07724	train-logloss:0.23812	eval-auc:0.97620	eval-error:0.08057	eval-logloss:0.23999
# [8]	train-auc:0.97980	train-error:0.07750	train-logloss:0.22260	eval-auc:0.97919	eval-error:0.08017	eval-logloss:0.22444
# [9]	train-auc:0.98485	train-error:0.06532	train-logloss:0.20215	eval-auc:0.98437	eval-error:0.06698	eval-logloss:0.20383
# [10]	train-auc:0.98724	train-error:0.06198	train-logloss:0.18828	eval-auc:0.98668	eval-error:0.06537	eval-logloss:0.19034
# [11]	train-auc:0.98841	train-error:0.05713	train-logloss:0.17732	eval-auc:0.98767	eval-error:0.06079	eval-logloss:0.17994
# [12]	train-auc:0.99118	train-error:0.04375	train-logloss:0.16016	eval-auc:0.99041	eval-error:0.04720	eval-logloss:0.16355
# [13]	train-auc:0.99286	train-error:0.03924	train-logloss:0.14898	eval-auc:0.99204	eval-error:0.04366	eval-logloss:0.15284
# [14]	train-auc:0.99347	train-error:0.03816	train-logloss:0.14354	eval-auc:0.99249	eval-error:0.04358	eval-logloss:0.14779
# [15]	train-auc:0.99432	train-error:0.03498	train-logloss:0.13264	eval-auc:0.99347	eval-error:0.03964	eval-logloss:0.13742
# [16]	train-auc:0.99592	train-error:0.02571	train-logloss:0.11672	eval-auc:0.99487	eval-error:0.03007	eval-logloss:0.12171
# [17]	train-auc:0.99669	train-error:0.02469	train-logloss:0.10985	eval-auc:0.99563	eval-error:0.02879	eval-logloss:0.11501
# [18]	train-auc:0.99692	train-error:0.02290	train-logloss:0.10455	eval-auc:0.99595	eval-error:0.02790	eval-logloss:0.10981
# [19]	train-auc:0.99722	train-error:0.02276	train-logloss:0.09967	eval-auc:0.99619	eval-error:0.02766	eval-logloss:0.10503
# [20]	train-auc:0.99781	train-error:0.01683	train-logloss:0.09068	eval-auc:0.99668	eval-error:0.02099	eval-logloss:0.09620
# [21]	train-auc:0.99798	train-error:0.01657	train-logloss:0.08609	eval-auc:0.99681	eval-error:0.02075	eval-logloss:0.09205
# [22]	train-auc:0.99838	train-error:0.01381	train-logloss:0.07799	eval-auc:0.99720	eval-error:0.01874	eval-logloss:0.08449
# [23]	train-auc:0.99858	train-error:0.01331	train-logloss:0.07281	eval-auc:0.99743	eval-error:0.01761	eval-logloss:0.07942
# [24]	train-auc:0.99889	train-error:0.01154	train-logloss:0.06944	eval-auc:0.99769	eval-error:0.01648	eval-logloss:0.07671
# [25]	train-auc:0.99898	train-error:0.01080	train-logloss:0.06697	eval-auc:0.99784	eval-error:0.01616	eval-logloss:0.07439
# [26]	train-auc:0.99902	train-error:0.01055	train-logloss:0.06548	eval-auc:0.99785	eval-error:0.01600	eval-logloss:0.07326
# [27]	train-auc:0.99921	train-error:0.01013	train-logloss:0.06200	eval-auc:0.99800	eval-error:0.01568	eval-logloss:0.07037
# [28]	train-auc:0.99924	train-error:0.00997	train-logloss:0.06024	eval-auc:0.99807	eval-error:0.01568	eval-logloss:0.06875
# [29]	train-auc:0.99934	train-error:0.00977	train-logloss:0.05696	eval-auc:0.99825	eval-error:0.01472	eval-logloss:0.06568
# [30]	train-auc:0.99941	train-error:0.00858	train-logloss:0.05365	eval-auc:0.99838	eval-error:0.01359	eval-logloss:0.06241
# [31]	train-auc:0.99945	train-error:0.00830	train-logloss:0.05133	eval-auc:0.99848	eval-error:0.01367	eval-logloss:0.06037
# [32]	train-auc:0.99950	train-error:0.00792	train-logloss:0.04948	eval-auc:0.99853	eval-error:0.01311	eval-logloss:0.05851
# [33]	train-auc:0.99955	train-error:0.00772	train-logloss:0.04803	eval-auc:0.99858	eval-error:0.01311	eval-logloss:0.05753
# [34]	train-auc:0.99958	train-error:0.00732	train-logloss:0.04651	eval-auc:0.99862	eval-error:0.01271	eval-logloss:0.05606
# [35]	train-auc:0.99960	train-error:0.00700	train-logloss:0.04527	eval-auc:0.99865	eval-error:0.01271	eval-logloss:0.05506
# [36]	train-auc:0.99965	train-error:0.00694	train-logloss:0.04186	eval-auc:0.99875	eval-error:0.01262	eval-logloss:0.05157
# [37]	train-auc:0.99969	train-error:0.00680	train-logloss:0.03958	eval-auc:0.99878	eval-error:0.01254	eval-logloss:0.04952
# [38]	train-auc:0.99970	train-error:0.00645	train-logloss:0.03904	eval-auc:0.99879	eval-error:0.01222	eval-logloss:0.04923
# [39]	train-auc:0.99972	train-error:0.00651	train-logloss:0.03757	eval-auc:0.99885	eval-error:0.01238	eval-logloss:0.04780
# [40]	train-auc:0.99974	train-error:0.00635	train-logloss:0.03583	eval-auc:0.99894	eval-error:0.01214	eval-logloss:0.04621
# [41]	train-auc:0.99976	train-error:0.00623	train-logloss:0.03452	eval-auc:0.99901	eval-error:0.01214	eval-logloss:0.04490
# [42]	train-auc:0.99978	train-error:0.00605	train-logloss:0.03367	eval-auc:0.99907	eval-error:0.01222	eval-logloss:0.04413
# [43]	train-auc:0.99980	train-error:0.00589	train-logloss:0.03247	eval-auc:0.99912	eval-error:0.01222	eval-logloss:0.04303
# [44]	train-auc:0.99980	train-error:0.00583	train-logloss:0.03193	eval-auc:0.99913	eval-error:0.01214	eval-logloss:0.04253
# [45]	train-auc:0.99981	train-error:0.00579	train-logloss:0.03130	eval-auc:0.99915	eval-error:0.01222	eval-logloss:0.04190
# [46]	train-auc:0.99982	train-error:0.00565	train-logloss:0.03051	eval-auc:0.99916	eval-error:0.01230	eval-logloss:0.04150
# [47]	train-auc:0.99983	train-error:0.00541	train-logloss:0.02963	eval-auc:0.99919	eval-error:0.01214	eval-logloss:0.04077
# [48]	train-auc:0.99984	train-error:0.00531	train-logloss:0.02932	eval-auc:0.99920	eval-error:0.01190	eval-logloss:0.04060
# [49]	train-auc:0.99985	train-error:0.00515	train-logloss:0.02825	eval-auc:0.99922	eval-error:0.01190	eval-logloss:0.03965
# [50]	train-auc:0.99986	train-error:0.00489	train-logloss:0.02779	eval-auc:0.99922	eval-error:0.01182	eval-logloss:0.03949
# [51]	train-auc:0.99986	train-error:0.00482	train-logloss:0.02730	eval-auc:0.99922	eval-error:0.01174	eval-logloss:0.03897
# [52]	train-auc:0.99987	train-error:0.00491	train-logloss:0.02663	eval-auc:0.99925	eval-error:0.01198	eval-logloss:0.03840
# [53]	train-auc:0.99988	train-error:0.00472	train-logloss:0.02619	eval-auc:0.99927	eval-error:0.01198	eval-logloss:0.03790
# [54]	train-auc:0.99988	train-error:0.00456	train-logloss:0.02579	eval-auc:0.99926	eval-error:0.01182	eval-logloss:0.03776
# [55]	train-auc:0.99989	train-error:0.00462	train-logloss:0.02512	eval-auc:0.99928	eval-error:0.01190	eval-logloss:0.03717
# [56]	train-auc:0.99989	train-error:0.00456	train-logloss:0.02395	eval-auc:0.99931	eval-error:0.01166	eval-logloss:0.03608
# [57]	train-auc:0.99990	train-error:0.00436	train-logloss:0.02362	eval-auc:0.99932	eval-error:0.01166	eval-logloss:0.03584
# [58]	train-auc:0.99990	train-error:0.00426	train-logloss:0.02341	eval-auc:0.99932	eval-error:0.01166	eval-logloss:0.03578
# [59]	train-auc:0.99992	train-error:0.00390	train-logloss:0.02221	eval-auc:0.99934	eval-error:0.01174	eval-logloss:0.03486
# [60]	train-auc:0.99992	train-error:0.00380	train-logloss:0.02141	eval-auc:0.99937	eval-error:0.01158	eval-logloss:0.03400
# [61]	train-auc:0.99992	train-error:0.00376	train-logloss:0.02098	eval-auc:0.99939	eval-error:0.01158	eval-logloss:0.03354
# [62]	train-auc:0.99992	train-error:0.00380	train-logloss:0.02076	eval-auc:0.99941	eval-error:0.01174	eval-logloss:0.03334
# [63]	train-auc:0.99993	train-error:0.00372	train-logloss:0.02046	eval-auc:0.99940	eval-error:0.01158	eval-logloss:0.03330
# [64]	train-auc:0.99993	train-error:0.00358	train-logloss:0.02017	eval-auc:0.99941	eval-error:0.01134	eval-logloss:0.03320
# [65]	train-auc:0.99993	train-error:0.00354	train-logloss:0.01989	eval-auc:0.99942	eval-error:0.01150	eval-logloss:0.03292
# [66]	train-auc:0.99994	train-error:0.00354	train-logloss:0.01972	eval-auc:0.99938	eval-error:0.01142	eval-logloss:0.03290
# [67]	train-auc:0.99994	train-error:0.00340	train-logloss:0.01938	eval-auc:0.99939	eval-error:0.01150	eval-logloss:0.03276
# [68]	train-auc:0.99995	train-error:0.00314	train-logloss:0.01883	eval-auc:0.99940	eval-error:0.01110	eval-logloss:0.03237
# [69]	train-auc:0.99995	train-error:0.00310	train-logloss:0.01855	eval-auc:0.99941	eval-error:0.01110	eval-logloss:0.03223
# [70]	train-auc:0.99995	train-error:0.00294	train-logloss:0.01822	eval-auc:0.99941	eval-error:0.01110	eval-logloss:0.03199
# [71]	train-auc:0.99995	train-error:0.00298	train-logloss:0.01793	eval-auc:0.99944	eval-error:0.01102	eval-logloss:0.03173
# [72]	train-auc:0.99996	train-error:0.00294	train-logloss:0.01774	eval-auc:0.99944	eval-error:0.01102	eval-logloss:0.03162
# [73]	train-auc:0.99996	train-error:0.00281	train-logloss:0.01706	eval-auc:0.99947	eval-error:0.01086	eval-logloss:0.03097
# [74]	train-auc:0.99996	train-error:0.00273	train-logloss:0.01671	eval-auc:0.99948	eval-error:0.01086	eval-logloss:0.03070
# [75]	train-auc:0.99996	train-error:0.00269	train-logloss:0.01661	eval-auc:0.99948	eval-error:0.01094	eval-logloss:0.03066
# [76]	train-auc:0.99996	train-error:0.00263	train-logloss:0.01646	eval-auc:0.99943	eval-error:0.01110	eval-logloss:0.03076
# [77]	train-auc:0.99997	train-error:0.00253	train-logloss:0.01616	eval-auc:0.99944	eval-error:0.01126	eval-logloss:0.03049
# [78]	train-auc:0.99997	train-error:0.00247	train-logloss:0.01575	eval-auc:0.99945	eval-error:0.01126	eval-logloss:0.03018
# [79]	train-auc:0.99997	train-error:0.00243	train-logloss:0.01543	eval-auc:0.99947	eval-error:0.01118	eval-logloss:0.02996
# [80]	train-auc:0.99997	train-error:0.00229	train-logloss:0.01500	eval-auc:0.99950	eval-error:0.01110	eval-logloss:0.02975
# [81]	train-auc:0.99997	train-error:0.00225	train-logloss:0.01459	eval-auc:0.99950	eval-error:0.01094	eval-logloss:0.02951
# [82]	train-auc:0.99998	train-error:0.00219	train-logloss:0.01439	eval-auc:0.99951	eval-error:0.01094	eval-logloss:0.02933
# [83]	train-auc:0.99998	train-error:0.00217	train-logloss:0.01413	eval-auc:0.99952	eval-error:0.01094	eval-logloss:0.02902
# [84]	train-auc:0.99998	train-error:0.00217	train-logloss:0.01408	eval-auc:0.99952	eval-error:0.01094	eval-logloss:0.02899
# [85]	train-auc:0.99998	train-error:0.00209	train-logloss:0.01392	eval-auc:0.99953	eval-error:0.01078	eval-logloss:0.02876
# [86]	train-auc:0.99998	train-error:0.00209	train-logloss:0.01382	eval-auc:0.99951	eval-error:0.01078	eval-logloss:0.02876
# [87]	train-auc:0.99998	train-error:0.00191	train-logloss:0.01360	eval-auc:0.99952	eval-error:0.01078	eval-logloss:0.02865
# [88]	train-auc:0.99998	train-error:0.00185	train-logloss:0.01343	eval-auc:0.99951	eval-error:0.01069	eval-logloss:0.02858
# [89]	train-auc:0.99998	train-error:0.00185	train-logloss:0.01334	eval-auc:0.99952	eval-error:0.01061	eval-logloss:0.02845
# [90]	train-auc:0.99998	train-error:0.00185	train-logloss:0.01327	eval-auc:0.99952	eval-error:0.01061	eval-logloss:0.02841
# [91]	train-auc:0.99998	train-error:0.00181	train-logloss:0.01318	eval-auc:0.99952	eval-error:0.01069	eval-logloss:0.02837
# [92]	train-auc:0.99998	train-error:0.00181	train-logloss:0.01293	eval-auc:0.99953	eval-error:0.01069	eval-logloss:0.02818
# [93]	train-auc:0.99998	train-error:0.00167	train-logloss:0.01261	eval-auc:0.99954	eval-error:0.01086	eval-logloss:0.02797
# [94]	train-auc:0.99998	train-error:0.00167	train-logloss:0.01247	eval-auc:0.99954	eval-error:0.01094	eval-logloss:0.02792
# [95]	train-auc:0.99998	train-error:0.00161	train-logloss:0.01236	eval-auc:0.99954	eval-error:0.01086	eval-logloss:0.02792
# [96]	train-auc:0.99999	train-error:0.00157	train-logloss:0.01218	eval-auc:0.99953	eval-error:0.01086	eval-logloss:0.02791
# [97]	train-auc:0.99999	train-error:0.00153	train-logloss:0.01202	eval-auc:0.99951	eval-error:0.01061	eval-logloss:0.02779
# [98]	train-auc:0.99999	train-error:0.00153	train-logloss:0.01172	eval-auc:0.99952	eval-error:0.01045	eval-logloss:0.02754
# [99]	train-auc:0.99999	train-error:0.00147	train-logloss:0.01158	eval-auc:0.99953	eval-error:0.01037	eval-logloss:0.02740
# [100]	train-auc:0.99999	train-error:0.00143	train-logloss:0.01146	eval-auc:0.99953	eval-error:0.01045	eval-logloss:0.02728
# [101]	train-auc:0.99999	train-error:0.00143	train-logloss:0.01138	eval-auc:0.99953	eval-error:0.01061	eval-logloss:0.02733
# [102]	train-auc:0.99999	train-error:0.00139	train-logloss:0.01121	eval-auc:0.99953	eval-error:0.01078	eval-logloss:0.02722
# [103]	train-auc:0.99999	train-error:0.00135	train-logloss:0.01089	eval-auc:0.99954	eval-error:0.01078	eval-logloss:0.02685
# [104]	train-auc:0.99999	train-error:0.00135	train-logloss:0.01062	eval-auc:0.99955	eval-error:0.01078	eval-logloss:0.02663
# [105]	train-auc:0.99999	train-error:0.00131	train-logloss:0.01051	eval-auc:0.99955	eval-error:0.01069	eval-logloss:0.02655
# [106]	train-auc:0.99999	train-error:0.00123	train-logloss:0.01044	eval-auc:0.99955	eval-error:0.01061	eval-logloss:0.02647
# [107]	train-auc:0.99999	train-error:0.00117	train-logloss:0.01032	eval-auc:0.99955	eval-error:0.01061	eval-logloss:0.02638
# [108]	train-auc:0.99999	train-error:0.00115	train-logloss:0.01018	eval-auc:0.99955	eval-error:0.01069	eval-logloss:0.02633
# [109]	train-auc:0.99999	train-error:0.00115	train-logloss:0.01013	eval-auc:0.99956	eval-error:0.01061	eval-logloss:0.02617
# [110]	train-auc:0.99999	train-error:0.00115	train-logloss:0.01005	eval-auc:0.99956	eval-error:0.01061	eval-logloss:0.02615
# [111]	train-auc:0.99999	train-error:0.00115	train-logloss:0.00988	eval-auc:0.99957	eval-error:0.01061	eval-logloss:0.02595
# [112]	train-auc:0.99999	train-error:0.00115	train-logloss:0.00981	eval-auc:0.99958	eval-error:0.01037	eval-logloss:0.02590
# [113]	train-auc:0.99999	train-error:0.00115	train-logloss:0.00959	eval-auc:0.99959	eval-error:0.01045	eval-logloss:0.02563
# [114]	train-auc:0.99999	train-error:0.00113	train-logloss:0.00954	eval-auc:0.99959	eval-error:0.01037	eval-logloss:0.02548
# [115]	train-auc:0.99999	train-error:0.00109	train-logloss:0.00936	eval-auc:0.99959	eval-error:0.01037	eval-logloss:0.02551
# [116]	train-auc:0.99999	train-error:0.00107	train-logloss:0.00929	eval-auc:0.99959	eval-error:0.01037	eval-logloss:0.02543
# [117]	train-auc:0.99999	train-error:0.00101	train-logloss:0.00919	eval-auc:0.99959	eval-error:0.01029	eval-logloss:0.02546
# [118]	train-auc:0.99999	train-error:0.00096	train-logloss:0.00910	eval-auc:0.99959	eval-error:0.01021	eval-logloss:0.02543
# [119]	train-auc:0.99999	train-error:0.00096	train-logloss:0.00908	eval-auc:0.99959	eval-error:0.01029	eval-logloss:0.02542
# [120]	train-auc:0.99999	train-error:0.00101	train-logloss:0.00895	eval-auc:0.99959	eval-error:0.01013	eval-logloss:0.02528
# [121]	train-auc:0.99999	train-error:0.00090	train-logloss:0.00873	eval-auc:0.99960	eval-error:0.01029	eval-logloss:0.02515
# [122]	train-auc:0.99999	train-error:0.00090	train-logloss:0.00866	eval-auc:0.99960	eval-error:0.01005	eval-logloss:0.02510
# [123]	train-auc:0.99999	train-error:0.00090	train-logloss:0.00851	eval-auc:0.99960	eval-error:0.00989	eval-logloss:0.02498
# [124]	train-auc:0.99999	train-error:0.00086	train-logloss:0.00831	eval-auc:0.99961	eval-error:0.00989	eval-logloss:0.02485
# [125]	train-auc:1.00000	train-error:0.00080	train-logloss:0.00822	eval-auc:0.99960	eval-error:0.01005	eval-logloss:0.02488
# [126]	train-auc:1.00000	train-error:0.00080	train-logloss:0.00820	eval-auc:0.99960	eval-error:0.00997	eval-logloss:0.02488
# [127]	train-auc:1.00000	train-error:0.00080	train-logloss:0.00804	eval-auc:0.99960	eval-error:0.00997	eval-logloss:0.02473
# [128]	train-auc:1.00000	train-error:0.00078	train-logloss:0.00791	eval-auc:0.99961	eval-error:0.00997	eval-logloss:0.02457
# [129]	train-auc:1.00000	train-error:0.00076	train-logloss:0.00779	eval-auc:0.99961	eval-error:0.00989	eval-logloss:0.02462
# [130]	train-auc:1.00000	train-error:0.00080	train-logloss:0.00775	eval-auc:0.99961	eval-error:0.00997	eval-logloss:0.02463
# [131]	train-auc:1.00000	train-error:0.00080	train-logloss:0.00771	eval-auc:0.99960	eval-error:0.00997	eval-logloss:0.02463
# [132]	train-auc:1.00000	train-error:0.00078	train-logloss:0.00769	eval-auc:0.99960	eval-error:0.01005	eval-logloss:0.02469
# [133]	train-auc:1.00000	train-error:0.00078	train-logloss:0.00768	eval-auc:0.99960	eval-error:0.01005	eval-logloss:0.02469
# [134]	train-auc:1.00000	train-error:0.00074	train-logloss:0.00756	eval-auc:0.99960	eval-error:0.01005	eval-logloss:0.02467
# [135]	train-auc:1.00000	train-error:0.00072	train-logloss:0.00743	eval-auc:0.99960	eval-error:0.00965	eval-logloss:0.02460
# [136]	train-auc:1.00000	train-error:0.00072	train-logloss:0.00741	eval-auc:0.99960	eval-error:0.00965	eval-logloss:0.02459
# [137]	train-auc:1.00000	train-error:0.00072	train-logloss:0.00738	eval-auc:0.99960	eval-error:0.00981	eval-logloss:0.02458
# [138]	train-auc:1.00000	train-error:0.00068	train-logloss:0.00729	eval-auc:0.99961	eval-error:0.00989	eval-logloss:0.02446
# [139]	train-auc:1.00000	train-error:0.00066	train-logloss:0.00719	eval-auc:0.99961	eval-error:0.00997	eval-logloss:0.02439
# [140]	train-auc:1.00000	train-error:0.00064	train-logloss:0.00704	eval-auc:0.99961	eval-error:0.00997	eval-logloss:0.02425
# [141]	train-auc:1.00000	train-error:0.00062	train-logloss:0.00695	eval-auc:0.99962	eval-error:0.00997	eval-logloss:0.02413
# [142]	train-auc:1.00000	train-error:0.00062	train-logloss:0.00687	eval-auc:0.99963	eval-error:0.00997	eval-logloss:0.02406
# [143]	train-auc:1.00000	train-error:0.00058	train-logloss:0.00674	eval-auc:0.99960	eval-error:0.00973	eval-logloss:0.02412
# [144]	train-auc:1.00000	train-error:0.00056	train-logloss:0.00656	eval-auc:0.99961	eval-error:0.00997	eval-logloss:0.02396
# [145]	train-auc:1.00000	train-error:0.00056	train-logloss:0.00642	eval-auc:0.99962	eval-error:0.00981	eval-logloss:0.02387
# [146]	train-auc:1.00000	train-error:0.00056	train-logloss:0.00637	eval-auc:0.99962	eval-error:0.00981	eval-logloss:0.02382
# [147]	train-auc:1.00000	train-error:0.00056	train-logloss:0.00636	eval-auc:0.99962	eval-error:0.00981	eval-logloss:0.02382
# [148]	train-auc:1.00000	train-error:0.00054	train-logloss:0.00627	eval-auc:0.99963	eval-error:0.00965	eval-logloss:0.02387
# [149]	train-auc:1.00000	train-error:0.00054	train-logloss:0.00620	eval-auc:0.99963	eval-error:0.00957	eval-logloss:0.02388
# [150]	train-auc:1.00000	train-error:0.00050	train-logloss:0.00611	eval-auc:0.99963	eval-error:0.00949	eval-logloss:0.02383
# [151]	train-auc:1.00000	train-error:0.00048	train-logloss:0.00600	eval-auc:0.99964	eval-error:0.00949	eval-logloss:0.02372
# [152]	train-auc:1.00000	train-error:0.00044	train-logloss:0.00594	eval-auc:0.99964	eval-error:0.00965	eval-logloss:0.02374
# [153]	train-auc:1.00000	train-error:0.00044	train-logloss:0.00586	eval-auc:0.99964	eval-error:0.00941	eval-logloss:0.02373
# [154]	train-auc:1.00000	train-error:0.00044	train-logloss:0.00580	eval-auc:0.99962	eval-error:0.00925	eval-logloss:0.02368
# [155]	train-auc:1.00000	train-error:0.00044	train-logloss:0.00578	eval-auc:0.99962	eval-error:0.00925	eval-logloss:0.02368
# [156]	train-auc:1.00000	train-error:0.00044	train-logloss:0.00578	eval-auc:0.99962	eval-error:0.00925	eval-logloss:0.02369
# [157]	train-auc:1.00000	train-error:0.00044	train-logloss:0.00573	eval-auc:0.99962	eval-error:0.00917	eval-logloss:0.02373
# [158]	train-auc:1.00000	train-error:0.00044	train-logloss:0.00565	eval-auc:0.99963	eval-error:0.00933	eval-logloss:0.02374
# [159]	train-auc:1.00000	train-error:0.00042	train-logloss:0.00554	eval-auc:0.99962	eval-error:0.00965	eval-logloss:0.02375
# [160]	train-auc:1.00000	train-error:0.00042	train-logloss:0.00547	eval-auc:0.99962	eval-error:0.00949	eval-logloss:0.02379
# [161]	train-auc:1.00000	train-error:0.00042	train-logloss:0.00540	eval-auc:0.99962	eval-error:0.00949	eval-logloss:0.02386
# [162]	train-auc:1.00000	train-error:0.00040	train-logloss:0.00535	eval-auc:0.99961	eval-error:0.00949	eval-logloss:0.02384
# [163]	train-auc:1.00000	train-error:0.00038	train-logloss:0.00529	eval-auc:0.99961	eval-error:0.00957	eval-logloss:0.02387
# [164]	train-auc:1.00000	train-error:0.00038	train-logloss:0.00524	eval-auc:0.99961	eval-error:0.00965	eval-logloss:0.02384
# [165]	train-auc:1.00000	train-error:0.00038	train-logloss:0.00520	eval-auc:0.99961	eval-error:0.00973	eval-logloss:0.02378

# %%
THRESHOLD = 0.5
preds = model.predict(dtest)
accuracy = accuracy_score(y_test, preds > THRESHOLD)
report = classification_report(y_test, preds > THRESHOLD, digits=4)

print(f"Accuracy: {accuracy:.4f}")
print("Classification Report:")
print(report)
# Out:
# Accuracy: 0.9903
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9904    0.9909    0.9907      6476
#            1     0.9901    0.9896    0.9898      5960
#
#     accuracy                         0.9903     12436
#    macro avg     0.9903    0.9902    0.9903     12436
# weighted avg     0.9903    0.9903    0.9903     12436

# %%
comparison = pd.DataFrame(preds, columns=["Predicted Probability"])
comparison["Predicted Label"] = (comparison["Predicted Probability"] > THRESHOLD).astype(int)
comparison["True Label"] = y_test.values
comparison["Attack Name"] = data_test["Attack Name"].values
comparison
# Out:
#        Predicted Probability  Predicted Label  True Label     Attack Name
# 0                   0.000729                0           0  Benign Traffic
# 1                   0.001192                0           0  Benign Traffic
# 2                   0.991024                1           1  MQTT Malformed
# 3                   0.001424                0           0  Benign Traffic
# 4                   0.000632                0           0  Benign Traffic
# ...                      ...              ...         ...             ...
# 12431               0.971185                1           1  DDoS UDP Flood
# 12432               0.000308                0           0  Benign Traffic
# 12433               0.995690                1           1  DoS ICMP Flood
# 12434               0.000754                0           0  Benign Traffic
# 12435               0.000650                0           0  Benign Traffic
#
# [12436 rows x 4 columns]

# %%
incorrect = comparison[comparison["Predicted Label"] != comparison["True Label"]]
incorrect["Attack Name"].value_counts()
# Out:
# Attack Name
# Benign Traffic              59
# DoS UDP Flood               23
# DoS ICMP Flood              12
# DDoS UDP Flood              11
# DDoS ICMP Flood             10
# MQTT Malformed               2
# Recon Vulnerability Scan     1
# MITM ARP Spoofing            1
# Recon Port Scan              1
# MQTT DoS Publish Flood       1
# Name: count, dtype: int64

# %% [markdown]
# # Hyperparameter Tuning

# %% [markdown]
# Random search CV was essentially used due to the large number of hyperparameters that could be tuned. Only the main ones after searching online as the most influential were tuned. The below did not use sklearn modules and interface in order to utilize gpu.

# %%
base_param = {
    'objective': 'binary:logistic',
    'eval_metric': ['auc', 'error', 'logloss'],
    'device': 'cuda',
    'verbosity': 1,
}
evallist = [(dtrain, 'train'), (dtest, 'eval')]

hyperparameter_grid = {
    "max_depth": [3, 5, 7, 9, 11, 13],
    "min_child_weight":[1, 2, 3, 4, 5, 6],
    "subsample":[0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
    "colsample_bytree": [0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
    "eta": [0.01, 0.03, 0.05, 0.1],
}

tested_params = set()
def sample_hyperparameters(grid: dict) -> dict[str, float | int]:
    params = {}
    for key, values in grid.items():
        params[key] = random.choice(values)
    return params

n_iters = 30

best_auc = 0.0
best_iter = -1
best_params = None

for i in range(n_iters):
    sampled_params = sample_hyperparameters(hyperparameter_grid)
    while frozenset(sampled_params.items()) in tested_params:
        sampled_params = sample_hyperparameters(hyperparameter_grid)

    tested_params.add(frozenset(sampled_params.items()))
    param = base_param.copy()
    param.update(sampled_params)
    model = xgb.train(param, dtrain, num_boost_round=2000, evals=evallist, early_stopping_rounds=10, verbose_eval=False)
    preds = model.predict(dtest)
    accuracy = accuracy_score(y_test, preds > THRESHOLD)
    auc = roc_auc_score(y_test, preds)
    precision = precision_score(y_test, preds > THRESHOLD)
    recall = recall_score(y_test, preds > THRESHOLD)
    f1 = f1_score(y_test, preds > THRESHOLD)

    print(f"Iteration {i+1}/{n_iters} - Params: {sampled_params} | Accuracy: {accuracy:.4f} | AUC: {auc:.4f} | Precision: {precision:.4f} | Recall: {recall:.4f} | F1-Score: {f1:.4f}")

    if auc > best_auc:
        best_auc = auc
        best_iter = i + 1
        best_params = sampled_params
        model.save_model(f"XGBModels/model_iter_{i+1}_acc_{accuracy:.4f}_auc_{auc:.4f}.json")

print(f"Best AUC: {best_auc:.4f} with params: {best_params} at iteration {best_iter}")
# Out:
# Iteration 1/30 - Params: {'max_depth': 9, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 1.0, 'eta': 0.05} | Accuracy: 0.9916 | AUC: 0.9996 | Precision: 0.9918 | Recall: 0.9908 | F1-Score: 0.9913
# Iteration 2/30 - Params: {'max_depth': 11, 'min_child_weight': 4, 'subsample': 0.5, 'colsample_bytree': 0.5, 'eta': 0.1} | Accuracy: 0.9893 | AUC: 0.9994 | Precision: 0.9896 | Recall: 0.9881 | F1-Score: 0.9888
# Iteration 3/30 - Params: {'max_depth': 7, 'min_child_weight': 2, 'subsample': 0.6, 'colsample_bytree': 0.8, 'eta': 0.03} | Accuracy: 0.9912 | AUC: 0.9996 | Precision: 0.9918 | Recall: 0.9898 | F1-Score: 0.9908
# Iteration 4/30 - Params: {'max_depth': 7, 'min_child_weight': 4, 'subsample': 0.8, 'colsample_bytree': 0.6, 'eta': 0.03} | Accuracy: 0.9907 | AUC: 0.9996 | Precision: 0.9916 | Recall: 0.9889 | F1-Score: 0.9903
# Iteration 5/30 - Params: {'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.5, 'colsample_bytree': 0.5, 'eta': 0.01} | Accuracy: 0.9620 | AUC: 0.9934 | Precision: 0.9780 | Recall: 0.9418 | F1-Score: 0.9596
# Iteration 6/30 - Params: {'max_depth': 11, 'min_child_weight': 1, 'subsample': 0.5, 'colsample_bytree': 0.9, 'eta': 0.01} | Accuracy: 0.9915 | AUC: 0.9995 | Precision: 0.9909 | Recall: 0.9913 | F1-Score: 0.9911
# Iteration 7/30 - Params: {'max_depth': 13, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.9, 'eta': 0.03} | Accuracy: 0.9910 | AUC: 0.9996 | Precision: 0.9914 | Recall: 0.9898 | F1-Score: 0.9906
# Iteration 8/30 - Params: {'max_depth': 11, 'min_child_weight': 4, 'subsample': 0.7, 'colsample_bytree': 1.0, 'eta': 0.03} | Accuracy: 0.9910 | AUC: 0.9996 | Precision: 0.9916 | Recall: 0.9896 | F1-Score: 0.9906
# Iteration 9/30 - Params: {'max_depth': 11, 'min_child_weight': 4, 'subsample': 0.7, 'colsample_bytree': 0.5, 'eta': 0.03} | Accuracy: 0.9910 | AUC: 0.9996 | Precision: 0.9918 | Recall: 0.9894 | F1-Score: 0.9906
# Iteration 10/30 - Params: {'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.6, 'colsample_bytree': 0.7, 'eta': 0.03} | Accuracy: 0.9900 | AUC: 0.9994 | Precision: 0.9909 | Recall: 0.9883 | F1-Score: 0.9896
# Iteration 11/30 - Params: {'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.6, 'colsample_bytree': 1.0, 'eta': 0.1} | Accuracy: 0.9912 | AUC: 0.9995 | Precision: 0.9916 | Recall: 0.9901 | F1-Score: 0.9908
# Iteration 12/30 - Params: {'max_depth': 11, 'min_child_weight': 4, 'subsample': 0.9, 'colsample_bytree': 1.0, 'eta': 0.03} | Accuracy: 0.9912 | AUC: 0.9996 | Precision: 0.9916 | Recall: 0.9899 | F1-Score: 0.9908
# Iteration 13/30 - Params: {'max_depth': 9, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 0.7, 'eta': 0.01} | Accuracy: 0.9908 | AUC: 0.9995 | Precision: 0.9916 | Recall: 0.9893 | F1-Score: 0.9904
# Iteration 14/30 - Params: {'max_depth': 13, 'min_child_weight': 1, 'subsample': 0.5, 'colsample_bytree': 0.5, 'eta': 0.05} | Accuracy: 0.9909 | AUC: 0.9995 | Precision: 0.9901 | Recall: 0.9909 | F1-Score: 0.9905
# Iteration 15/30 - Params: {'max_depth': 9, 'min_child_weight': 4, 'subsample': 0.5, 'colsample_bytree': 0.7, 'eta': 0.01} | Accuracy: 0.9901 | AUC: 0.9994 | Precision: 0.9906 | Recall: 0.9888 | F1-Score: 0.9897
# Iteration 16/30 - Params: {'max_depth': 11, 'min_child_weight': 6, 'subsample': 0.5, 'colsample_bytree': 0.5, 'eta': 0.1} | Accuracy: 0.9897 | AUC: 0.9994 | Precision: 0.9904 | Recall: 0.9881 | F1-Score: 0.9892
# Iteration 17/30 - Params: {'max_depth': 7, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 0.5, 'eta': 0.1} | Accuracy: 0.9903 | AUC: 0.9995 | Precision: 0.9908 | Recall: 0.9889 | F1-Score: 0.9898
# Iteration 18/30 - Params: {'max_depth': 11, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.8, 'eta': 0.03} | Accuracy: 0.9904 | AUC: 0.9995 | Precision: 0.9913 | Recall: 0.9888 | F1-Score: 0.9900
# Iteration 19/30 - Params: {'max_depth': 9, 'min_child_weight': 4, 'subsample': 0.5, 'colsample_bytree': 0.8, 'eta': 0.1} | Accuracy: 0.9904 | AUC: 0.9995 | Precision: 0.9903 | Recall: 0.9896 | F1-Score: 0.9899
# Iteration 20/30 - Params: {'max_depth': 11, 'min_child_weight': 4, 'subsample': 0.7, 'colsample_bytree': 0.8, 'eta': 0.01} | Accuracy: 0.9912 | AUC: 0.9996 | Precision: 0.9918 | Recall: 0.9899 | F1-Score: 0.9908
# Iteration 21/30 - Params: {'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.5, 'colsample_bytree': 0.7, 'eta': 0.1} | Accuracy: 0.9887 | AUC: 0.9990 | Precision: 0.9891 | Recall: 0.9874 | F1-Score: 0.9882
# Iteration 22/30 - Params: {'max_depth': 9, 'min_child_weight': 1, 'subsample': 0.5, 'colsample_bytree': 0.5, 'eta': 0.01} | Accuracy: 0.9909 | AUC: 0.9994 | Precision: 0.9904 | Recall: 0.9906 | F1-Score: 0.9905
# Iteration 23/30 - Params: {'max_depth': 3, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.7, 'eta': 0.01} | Accuracy: 0.9661 | AUC: 0.9939 | Precision: 0.9782 | Recall: 0.9503 | F1-Score: 0.9641
# Iteration 24/30 - Params: {'max_depth': 11, 'min_child_weight': 5, 'subsample': 0.9, 'colsample_bytree': 0.5, 'eta': 0.05} | Accuracy: 0.9905 | AUC: 0.9996 | Precision: 0.9906 | Recall: 0.9896 | F1-Score: 0.9901
# Iteration 25/30 - Params: {'max_depth': 3, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 0.6, 'eta': 0.01} | Accuracy: 0.9694 | AUC: 0.9943 | Precision: 0.9779 | Recall: 0.9579 | F1-Score: 0.9678
# Iteration 26/30 - Params: {'max_depth': 11, 'min_child_weight': 1, 'subsample': 0.9, 'colsample_bytree': 0.7, 'eta': 0.01} | Accuracy: 0.9918 | AUC: 0.9996 | Precision: 0.9913 | Recall: 0.9916 | F1-Score: 0.9914
# Iteration 27/30 - Params: {'max_depth': 9, 'min_child_weight': 2, 'subsample': 0.5, 'colsample_bytree': 0.9, 'eta': 0.01} | Accuracy: 0.9907 | AUC: 0.9995 | Precision: 0.9918 | Recall: 0.9888 | F1-Score: 0.9903
# Iteration 28/30 - Params: {'max_depth': 7, 'min_child_weight': 6, 'subsample': 0.5, 'colsample_bytree': 0.8, 'eta': 0.01} | Accuracy: 0.9887 | AUC: 0.9992 | Precision: 0.9897 | Recall: 0.9867 | F1-Score: 0.9882
# Iteration 29/30 - Params: {'max_depth': 9, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.8, 'eta': 0.05} | Accuracy: 0.9900 | AUC: 0.9995 | Precision: 0.9903 | Recall: 0.9889 | F1-Score: 0.9896
# Iteration 30/30 - Params: {'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 1.0, 'eta': 0.03} | Accuracy: 0.9862 | AUC: 0.9985 | Precision: 0.9864 | Recall: 0.9849 | F1-Score: 0.9856
# Best AUC: 0.9996 with params: {'max_depth': 9, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 1.0, 'eta': 0.05} at iteration 1

# %%
best_model = xgb.XGBClassifier(device='cuda')
best_model.load_model("XGBModels/model_iter_1_acc_0.9916_auc_0.9996.json")

# %%
def calculate_metrics(y_true, preds, threshold):
    preds_label = (preds > threshold).astype(int)
    accuracy = accuracy_score(y_true, preds_label)
    precision = precision_score(y_true, preds_label)
    recall = recall_score(y_true, preds_label)
    f1 = f1_score(y_true, preds_label)
    auc = roc_auc_score(y_true, preds)
    print(f"Best Model Evaluation using threshold {threshold}:")
    print(f"Best Model Accuracy: {accuracy:.4f}")
    print(f"Best Model AUC: {auc:.4f}")
    print(f"Best Model F1 Score: {f1:.4f}")
    print(f"Best Model Recall: {recall:.4f}")
    print(f"Best Model Precision: {precision:.4f}")

# %%
THRESHOLD = 0.5
preds = best_model.predict(X_test)
calculate_metrics(y_test, preds, THRESHOLD)
# Out:
# Best Model Evaluation using threshold 0.5:
# Best Model Accuracy: 0.9916
# Best Model AUC: 0.9916
# Best Model F1 Score: 0.9913
# Best Model Recall: 0.9908
# Best Model Precision: 0.9918

# %%
# See performance at different thresholds
for threshold in [0.2, 0.4, 0.5, 0.6, 0.8]:
    calculate_metrics(y_test, preds, threshold)
    print("\n")
# Out:
# Best Model Evaluation using threshold 0.2:
# Best Model Accuracy: 0.9916
# Best Model AUC: 0.9916
# Best Model F1 Score: 0.9913
# Best Model Recall: 0.9908
# Best Model Precision: 0.9918
#
#
# Best Model Evaluation using threshold 0.4:
# Best Model Accuracy: 0.9916
# Best Model AUC: 0.9916
# Best Model F1 Score: 0.9913
# Best Model Recall: 0.9908
# Best Model Precision: 0.9918
#
#
# Best Model Evaluation using threshold 0.5:
# Best Model Accuracy: 0.9916
# Best Model AUC: 0.9916
# Best Model F1 Score: 0.9913
# Best Model Recall: 0.9908
# Best Model Precision: 0.9918
#
#
# Best Model Evaluation using threshold 0.6:
# Best Model Accuracy: 0.9916
# Best Model AUC: 0.9916
# Best Model F1 Score: 0.9913
# Best Model Recall: 0.9908
# Best Model Precision: 0.9918
#
#
# Best Model Evaluation using threshold 0.8:
# Best Model Accuracy: 0.9916
# Best Model AUC: 0.9916
# Best Model F1 Score: 0.9913
# Best Model Recall: 0.9908
# Best Model Precision: 0.9918

# %% [markdown]
# Doesn't seem like there's a big difference for using different thresholds. 0.5 seems to give the best balance between accuracy, precision, recall, and f1-score.

# %% [markdown]
# # Feature Importances

# %%
perm_importance = permutation_importance(best_model, X_test, y_test, n_repeats=10, random_state=RANDOM_SEED, scoring=['roc_auc', 'accuracy'])

# %%
auc_importances = pd.DataFrame(perm_importance['roc_auc']['importances_mean'], index=X_test.columns, columns=['Importance']).sort_values(by='Importance', ascending=False)
accuracy_importances = pd.DataFrame(perm_importance['accuracy']['importances_mean'], index=X_test.columns, columns=['Importance']).sort_values(by='Importance', ascending=False)

# %%
pd.set_option('display.float_format', lambda x: '%.8f' % x)
auc_importances.head(10)
# Out:
#                     Importance
# Src Port            0.11045975
# Bwd Init Win Bytes  0.00541093
# ACK Flag Count      0.00534028
# Dst Port            0.00304108
# Flow Duration       0.00062137
# Bwd Packets/s       0.00058703
# FWD Init Win Bytes  0.00052730
# Active Mean         0.00029287
# Fwd IAT Std         0.00011969
# Flow IAT Mean       0.00011389

# %%
pd.set_option('display.float_format', lambda x: '%.8f' % x)
accuracy_importances.head(10)
# Out:
#                        Importance
# Src Port               0.24816661
# Bwd Init Win Bytes     0.07504021
# ACK Flag Count         0.04840785
# Dst Port               0.01955613
# Bwd Packets/s          0.01225474
# FWD Init Win Bytes     0.00708427
# Flow Duration          0.00467996
# Flow IAT Std           0.00161628
# Fwd Packet Length Std  0.00140720
# Active Mean            0.00116597
