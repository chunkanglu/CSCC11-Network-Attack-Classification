# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from pandas.api.types import CategoricalDtype
# Out:
# Caching the list of root modules, please wait!
# (This will only be done once - type '%rehashx' to reset cache!)

# %% [markdown]
# # (Ignore) Combining the data files

# %%
DATA_DIR = "data/"
# benign = pd.read_csv(DATA_DIR + "Benign Traffic.csv")
# ddos_icmp = pd.read_csv(DATA_DIR + "DDoS ICMP Flood.csv")
# ddos_udp = pd.read_csv(DATA_DIR + "DDoS UDP Flood.csv")
# dos_icmp = pd.read_csv(DATA_DIR + "DoS ICMP Flood.csv")
# dos_tcp = pd.read_csv(DATA_DIR + "DoS TCP Flood.csv")
# dos_udp = pd.read_csv(DATA_DIR + "DoS UDP Flood.csv")
# mitm_arp = pd.read_csv(DATA_DIR + "MITM ARP Spoofing.csv")
# ddos_publish = pd.read_csv(DATA_DIR + "MQTT DDoS Publish Flood.csv")
# dos_connect = pd.read_csv(DATA_DIR + "MQTT DoS Connect Flood.csv")
# dos_publish = pd.read_csv(DATA_DIR + "MQTT DoS Publish Flood.csv")
# mqtt_malformed = pd.read_csv(DATA_DIR + "MQTT Malformed.csv")
# os_scan = pd.read_csv(DATA_DIR + "Recon OS Scan.csv")
# ping_sweep = pd.read_csv(DATA_DIR + "Recon Ping Sweep.csv")
# port_scan = pd.read_csv(DATA_DIR + "Recon Port Scan.csv")
# vuln_scan = pd.read_csv(DATA_DIR + "Recon Vulnerability Scan.csv")

# # Combine all dataframes into a single dataframe and export to parquet
# all_data = pd.concat([
#     benign,
#     ddos_icmp,
#     ddos_udp,
#     dos_icmp,
#     dos_tcp,
#     dos_udp,
#     mitm_arp,
#     ddos_publish,
#     dos_connect,
#     dos_publish,
#     mqtt_malformed,
#     os_scan,
#     ping_sweep,
#     port_scan,
#     vuln_scan
# ], ignore_index=True)
# all_data.to_parquet(DATA_DIR + "combined_traffic.parquet", index=False)

# %% [markdown]
# # Initial Data Exploration

# %%
data = pd.read_parquet(DATA_DIR + "combined_traffic.parquet")

# %%
data["Timestamp"] = pd.to_datetime(data["Timestamp"], infer_datetime_format=True)
data["Attack Name"] = data["Attack Name"].astype("category")
attack_order = [
    "Benign",
    "DDoS ICMP Flood",
    "DDoS UDP Flood",
    "DoS ICMP Flood",
    "DoS TCP Flood",
    "DoS UDP Flood",
    "MITM ARP Spoofing",
    "MQTT DDoS Publish Flood",
    "MQTT DoS Connect Flood",
    "MQTT DoS Publish Flood",
    "MQTT Malformed",
    "Recon OS Scan",
    "Recon Ping Sweep",
    "Recon Port Scan",
    "Recon Vulnerability Scan"
]
cat_type = CategoricalDtype(categories=attack_order, ordered=True)
data["Attack Name"] = data["Attack Name"].astype(cat_type)
data["Attack Type"] = data["Attack Name"].cat.codes
# attack_mapping = {
#     "Benign": 0,
#     "DDoS ICMP Flood": 1,
#     "DDoS UDP Flood": 2,
#     "DoS ICMP Flood": 3,
#     "DoS TCP Flood": 4,
#     "DoS UDP Flood": 5,
#     "MITM ARP Spoofing": 6,
#     "MQTT DDoS Publish Flood": 7,
#     "MQTT DoS Connect Flood": 8,
#     "MQTT DoS Publish Flood": 9,
#     "MQTT Malformed": 10,
#     "Recon OS Scan": 11,
#     "Recon Ping Sweep": 12,
#     "Recon Port Scan": 13,
#     "Recon Vulnerability Scan": 14
# }
data.head()
# Out:
# /tmp/ipykernel_715498/2624595614.py:2: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   data["Timestamp"] = pd.to_datetime(data["Timestamp"], infer_datetime_format=True)
# /tmp/ipykernel_715498/2624595614.py:2: UserWarning: Parsing dates in %d/%m/%Y %I:%M:%S %p format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data["Timestamp"] = pd.to_datetime(data["Timestamp"], infer_datetime_format=True)
#                                       Flow ID         Src IP  Src Port  \
# 0     34.173.20.6-192.168.137.234-443-58644-6    34.173.20.6       443
# 1     34.173.20.6-192.168.137.234-443-58646-6    34.173.20.6       443
# 2  52.40.210.103-192.168.137.40-18665-60378-6  52.40.210.103     18665
# 3            10.0.0.3-10.0.0.254-44505-1883-6       10.0.0.3     44505
# 4            10.0.0.7-10.0.0.254-45727-1883-6       10.0.0.7     45727
#
#             Dst IP  Dst Port  Protocol           Timestamp  Flow Duration  \
# 0  192.168.137.234     58644         6 2023-09-14 09:24:26       14746364
# 1  192.168.137.234     58646         6 2023-09-14 09:24:41       60102110
# 2   192.168.137.40     60378         6 2023-09-14 09:24:14       90106769
# 3       10.0.0.254      1883         6 2023-09-14 09:24:15      119998980
# 4       10.0.0.254      1883         6 2023-09-14 09:24:15      119998539
#
#    Total Fwd Packet  Total Bwd packets  ...  Active Std  Active Max  \
# 0                 6                  0  ...         0.0         0.0
# 1                18                  0  ...         0.0    219123.0
# 2                 9                  0  ...         0.0    582529.0
# 3               123                123  ...         0.0         0.0
# 4               123                123  ...         0.0         0.0
#
#    Active Min   Idle Mean       Idle Std    Idle Max    Idle Min  Attack Name  \
# 0         0.0  14681116.0       0.000000  14681116.0  14681116.0          NaN
# 1    219123.0  14957706.0  190543.248665  15061923.0  14672051.0          NaN
# 2    582529.0  29841412.0  319090.538141  30049066.0  29473997.0          NaN
# 3         0.0         0.0       0.000000         0.0         0.0          NaN
# 4         0.0         0.0       0.000000         0.0         0.0          NaN
#
#    Label  Attack Type
# 0      0           -1
# 1      0           -1
# 2      0           -1
# 3      0           -1
# 4      0           -1
#
# [5 rows x 86 columns]

# %%
# Counts for each type of attack
data["Attack Name"].value_counts()
# Out:
# Attack Name
# DoS TCP Flood               2106916
# Recon Port Scan              485522
# MQTT DDoS Publish Flood      413913
# MQTT DoS Connect Flood       238031
# Recon OS Scan                 85317
# Benign Traffic                32620
# Recon Vulnerability Scan       8321
# DoS UDP Flood                  3115
# DDoS UDP Flood                 2576
# DDoS ICMP Flood                2552
# MQTT Malformed                 2246
# DoS ICMP Flood                 2107
# MITM ARP Spoofing              1053
# MQTT DoS Publish Flood          953
# Recon Ping Sweep                 71
# Name: count, dtype: int64

# %% [markdown]
# **Note**: Distribution for each type of attack & benign wildly varies. There's only 32620 benign, but orders of magnitude more for DoS TCP Flood. We may want to take subsets to have a better distribution and not have crazy class imbalance which can cause issues with biased predictions.

# %%
# No missing values
data.isna().sum().sum()
# Out:
# np.int64(0)

# %%
not_useful_columns = [
    "Flow ID",
    "Src IP",
    "Dst IP",
    "Attack Name",
]

# %%
# Datatypes of each column
pd.set_option('display.max_rows', None)  # To display all rows if there are many columns
data.dtypes
# Out:
# Flow ID                               object
# Src IP                                object
# Src Port                               int64
# Dst IP                                object
# Dst Port                               int64
# Protocol                               int64
# Timestamp                     datetime64[ns]
# Flow Duration                          int64
# Total Fwd Packet                       int64
# Total Bwd packets                      int64
# Total Length of Fwd Packet           float64
# Total Length of Bwd Packet           float64
# Fwd Packet Length Max                float64
# Fwd Packet Length Min                float64
# Fwd Packet Length Mean               float64
# Fwd Packet Length Std                float64
# Bwd Packet Length Max                float64
# Bwd Packet Length Min                float64
# Bwd Packet Length Mean               float64
# Bwd Packet Length Std                float64
# Flow Bytes/s                         float64
# Flow Packets/s                       float64
# Flow IAT Mean                        float64
# Flow IAT Std                         float64
# Flow IAT Max                         float64
# Flow IAT Min                         float64
# Fwd IAT Total                        float64
# Fwd IAT Mean                         float64
# Fwd IAT Std                          float64
# Fwd IAT Max                          float64
# Fwd IAT Min                          float64
# Bwd IAT Total                        float64
# Bwd IAT Mean                         float64
# Bwd IAT Std                          float64
# Bwd IAT Max                          float64
# Bwd IAT Min                          float64
# Fwd PSH Flags                          int64
# Bwd PSH Flags                          int64
# Fwd URG Flags                          int64
# Bwd URG Flags                          int64
# Fwd Header Length                      int64
# Bwd Header Length                      int64
# Fwd Packets/s                        float64
# Bwd Packets/s                        float64
# Packet Length Min                    float64
# Packet Length Max                    float64
# Packet Length Mean                   float64
# Packet Length Std                    float64
# Packet Length Variance               float64
# FIN Flag Count                         int64
# SYN Flag Count                         int64
# RST Flag Count                         int64
# PSH Flag Count                         int64
# ACK Flag Count                         int64
# URG Flag Count                         int64
# CWR Flag Count                         int64
# ECE Flag Count                         int64
# Down/Up Ratio                        float64
# Average Packet Size                  float64
# Fwd Segment Size Avg                 float64
# Bwd Segment Size Avg                 float64
# Fwd Bytes/Bulk Avg                     int64
# Fwd Packet/Bulk Avg                    int64
# Fwd Bulk Rate Avg                      int64
# Bwd Bytes/Bulk Avg                     int64
# Bwd Packet/Bulk Avg                    int64
# Bwd Bulk Rate Avg                      int64
# Subflow Fwd Packets                    int64
# Subflow Fwd Bytes                      int64
# Subflow Bwd Packets                    int64
# Subflow Bwd Bytes                      int64
# FWD Init Win Bytes                     int64
# Bwd Init Win Bytes                     int64
# Fwd Act Data Pkts                      int64
# Fwd Seg Size Min                       int64
# Active Mean                          float64
# Active Std                           float64
# Active Max                           float64
# Active Min                           float64
# Idle Mean                            float64
# Idle Std                             float64
# Idle Max                             float64
# Idle Min                             float64
# Attack Name                         category
# Label                                  int64
# Attack Type                             int8
# dtype: object

# %%
# corr_matrix = data.drop(not_useful_columns, axis=1).corr()
corr_matrix = pd.read_csv(DATA_DIR + "correlation_matrix.csv", index_col=0)
# Out:
#                             Src Port  Dst Port  Protocol  Timestamp  \
# Src Port                    1.000000 -0.402987       NaN  -0.142296
# Dst Port                   -0.402987  1.000000       NaN   0.517558
# Protocol                         NaN       NaN       NaN        NaN
# Timestamp                  -0.142296  0.517558       NaN   1.000000
# Flow Duration               0.250639 -0.557067       NaN  -0.331726
# Total Fwd Packet            0.046628 -0.075297       NaN  -0.054052
# Total Bwd packets           0.006619 -0.003399       NaN   0.009746
# Total Length of Fwd Packet  0.010090 -0.008985       NaN  -0.000688
# Total Length of Bwd Packet -0.015181  0.013538       NaN  -0.000746
# Fwd Packet Length Max       0.090031 -0.082516       NaN  -0.027470
# Fwd Packet Length Min       0.059994 -0.056800       NaN  -0.034595
# Fwd Packet Length Mean      0.089277 -0.083647       NaN  -0.044878
# Fwd Packet Length Std       0.080545 -0.073333       NaN  -0.020742
# Bwd Packet Length Max      -0.138095  0.131399       NaN  -0.060229
# Bwd Packet Length Min      -0.076039  0.072660       NaN  -0.033187
# Bwd Packet Length Mean     -0.130094  0.124009       NaN  -0.059375
# Bwd Packet Length Std      -0.126814  0.120340       NaN  -0.056537
# Flow Bytes/s                0.000733 -0.000304       NaN  -0.003664
# Flow Packets/s              0.014555 -0.014290       NaN  -0.017020
# Flow IAT Mean               0.202354 -0.455705       NaN  -0.214554
# Flow IAT Std                0.136199 -0.274941       NaN  -0.082368
# Flow IAT Max                0.170093 -0.359926       NaN  -0.150760
# Flow IAT Min                0.184087 -0.394626       NaN  -0.211710
# Fwd IAT Total               0.249345 -0.556248       NaN  -0.339891
# Fwd IAT Mean                0.199664 -0.465123       NaN  -0.234683
# Fwd IAT Std                 0.128907 -0.261931       NaN  -0.070496
# Fwd IAT Max                 0.169201 -0.363192       NaN  -0.168827
# Fwd IAT Min                 0.186518 -0.423111       NaN  -0.285731
# Bwd IAT Total               0.058401 -0.082600       NaN   0.289377
# Bwd IAT Mean                0.048238 -0.062378       NaN   0.199890
# Bwd IAT Std                 0.044170 -0.062403       NaN   0.170117
# Bwd IAT Max                 0.047342 -0.064942       NaN   0.204112
# Bwd IAT Min                 0.021007 -0.020861       NaN   0.088345
# Fwd PSH Flags               0.063029 -0.079618       NaN   0.218135
# Bwd PSH Flags                    NaN       NaN       NaN        NaN
# Fwd URG Flags               0.003974 -0.002807       NaN   0.007459
# Bwd URG Flags                    NaN       NaN       NaN        NaN
# Fwd Header Length           0.034808 -0.052362       NaN  -0.032687
# Bwd Header Length           0.006922 -0.004322       NaN   0.008162
# Fwd Packets/s               0.016105 -0.015783       NaN  -0.016078
# Bwd Packets/s               0.001913 -0.002004       NaN  -0.003482
# Packet Length Min           0.027302 -0.024087       NaN  -0.004669
# Packet Length Max          -0.041388  0.041552       NaN  -0.069531
# Packet Length Mean         -0.009775  0.010685       NaN  -0.074391
# Packet Length Std          -0.052318  0.051171       NaN  -0.068782
# Packet Length Variance     -0.057375  0.055646       NaN  -0.065436
# FIN Flag Count              0.015090 -0.013024       NaN  -0.139347
# SYN Flag Count             -0.044921  0.295728       NaN   0.317159
# RST Flag Count             -0.398522  0.638621       NaN   0.210034
# PSH Flag Count              0.012537 -0.010753       NaN   0.003538
# ACK Flag Count              0.010968 -0.008731       NaN   0.007461
# URG Flag Count             -0.003177  0.003398       NaN   0.014874
# CWR Flag Count              0.001189  0.001479       NaN   0.007318
# ECE Flag Count             -0.002331  0.004930       NaN   0.011800
# Down/Up Ratio              -0.101601  0.203009       NaN   0.181389
# Average Packet Size        -0.006716  0.007738       NaN  -0.074093
# Fwd Segment Size Avg        0.089277 -0.083647       NaN  -0.044878
# Bwd Segment Size Avg       -0.130094  0.124009       NaN  -0.059375
# Fwd Bytes/Bulk Avg               NaN       NaN       NaN        NaN
# Fwd Packet/Bulk Avg              NaN       NaN       NaN        NaN
# Fwd Bulk Rate Avg                NaN       NaN       NaN        NaN
# Bwd Bytes/Bulk Avg         -0.000475  0.001538       NaN  -0.005807
# Bwd Packet/Bulk Avg         0.005266 -0.002974       NaN  -0.009021
# Bwd Bulk Rate Avg          -0.000180  0.000548       NaN  -0.003785
# Subflow Fwd Packets         0.013602 -0.014794       NaN  -0.011724
# Subflow Fwd Bytes           0.009082 -0.006979       NaN  -0.003796
# Subflow Bwd Packets         0.008293 -0.006206       NaN  -0.005784
# Subflow Bwd Bytes          -0.006095  0.005929       NaN   0.000038
# FWD Init Win Bytes          0.116839 -0.115621       NaN  -0.208698
# Bwd Init Win Bytes          0.089440 -0.061947       NaN  -0.040932
# Fwd Act Data Pkts           0.017795 -0.015842       NaN   0.005961
# Fwd Seg Size Min            0.156886 -0.158653       NaN  -0.057735
# Active Mean                 0.068810 -0.160626       NaN  -0.130032
# Active Std                  0.058164 -0.168343       NaN  -0.092529
# Active Max                  0.076095 -0.194154       NaN  -0.139780
# Active Min                  0.051570 -0.115487       NaN  -0.108281
# Idle Mean                   0.138516 -0.330297       NaN  -0.101572
# Idle Std                    0.094362 -0.204830       NaN  -0.115079
# Idle Max                    0.141558 -0.311831       NaN  -0.118649
# Idle Min                    0.117423 -0.281328       NaN  -0.056302
# Label                      -0.037207  0.054486       NaN  -0.375797
# Attack Type                -0.232306  0.673504       NaN   0.666840
#
#                             Flow Duration  Total Fwd Packet  \
# Src Port                         0.250639          0.046628
# Dst Port                        -0.557067         -0.075297
# Protocol                              NaN               NaN
# Timestamp                       -0.331726         -0.054052
# Flow Duration                    1.000000          0.153756
# Total Fwd Packet                 0.153756          1.000000
# Total Bwd packets                0.007762          0.901475
# Total Length of Fwd Packet       0.004774          0.756779
# Total Length of Bwd Packet      -0.004466          0.220604
# Fwd Packet Length Max           -0.111181          0.120204
# Fwd Packet Length Min           -0.071102         -0.002892
# Fwd Packet Length Mean          -0.105367          0.057238
# Fwd Packet Length Std           -0.104294          0.086482
# Bwd Packet Length Max           -0.122963          0.021250
# Bwd Packet Length Min           -0.066605         -0.010922
# Bwd Packet Length Mean          -0.113522          0.003524
# Bwd Packet Length Std           -0.115336          0.007530
# Flow Bytes/s                    -0.007077         -0.000708
# Flow Packets/s                  -0.034046         -0.005232
# Flow IAT Mean                    0.583800          0.000622
# Flow IAT Std                     0.329318         -0.016489
# Flow IAT Max                     0.438382         -0.003556
# Flow IAT Min                     0.488636          0.018142
# Fwd IAT Total                    0.998352          0.153993
# Fwd IAT Mean                     0.591023          0.002291
# Fwd IAT Std                      0.311973         -0.016973
# Fwd IAT Max                      0.441429         -0.002361
# Fwd IAT Min                      0.520741          0.022759
# Bwd IAT Total                    0.084986          0.166718
# Bwd IAT Mean                     0.032316         -0.007856
# Bwd IAT Std                      0.017712         -0.008722
# Bwd IAT Max                      0.028485          0.000865
# Bwd IAT Min                      0.013752         -0.004665
# Fwd PSH Flags                    0.023205          0.053557
# Bwd PSH Flags                         NaN               NaN
# Fwd URG Flags                   -0.004104         -0.000656
# Bwd URG Flags                         NaN               NaN
# Fwd Header Length                0.100323          0.997758
# Bwd Header Length                0.008214          0.901563
# Fwd Packets/s                   -0.032272         -0.004970
# Bwd Packets/s                   -0.008478         -0.001078
# Packet Length Min               -0.028703         -0.000418
# Packet Length Max               -0.166480          0.087170
# Packet Length Mean              -0.149917          0.029909
# Packet Length Std               -0.162210          0.056716
# Packet Length Variance          -0.144382          0.039042
# FIN Flag Count                  -0.213753         -0.021927
# SYN Flag Count                  -0.515781         -0.055959
# RST Flag Count                  -0.736285         -0.113055
# PSH Flag Count                   0.011362          0.851234
# ACK Flag Count                   0.009815          0.967337
# URG Flag Count                  -0.008296         -0.001366
# CWR Flag Count                  -0.003159          0.002454
# ECE Flag Count                  -0.006572          0.000085
# Down/Up Ratio                   -0.201869         -0.031722
# Average Packet Size             -0.149946          0.026067
# Fwd Segment Size Avg            -0.105367          0.057238
# Bwd Segment Size Avg            -0.113522          0.003524
# Fwd Bytes/Bulk Avg                    NaN               NaN
# Fwd Packet/Bulk Avg                   NaN               NaN
# Fwd Bulk Rate Avg                     NaN               NaN
# Bwd Bytes/Bulk Avg              -0.005702          0.649704
# Bwd Packet/Bulk Avg              0.003006          0.834775
# Bwd Bulk Rate Avg               -0.007117         -0.000619
# Subflow Fwd Packets              0.015214          0.588639
# Subflow Fwd Bytes                0.007991          0.604672
# Subflow Bwd Packets              0.006993          0.569724
# Subflow Bwd Bytes               -0.001141          0.127106
# FWD Init Win Bytes              -0.270190         -0.010547
# Bwd Init Win Bytes              -0.149138         -0.016565
# Fwd Act Data Pkts                0.013692          0.938218
# Fwd Seg Size Min                -0.214014          0.034233
# Active Mean                      0.287282          0.047647
# Active Std                       0.258291          0.045305
# Active Max                       0.334846          0.056866
# Active Min                       0.222324          0.036009
# Idle Mean                        0.383921         -0.011962
# Idle Std                         0.281856         -0.010718
# Idle Max                         0.387700         -0.013463
# Idle Min                         0.296685         -0.008028
# Label                           -0.061755         -0.021827
# Attack Type                     -0.702953         -0.096840
#
#                             Total Bwd packets  Total Length of Fwd Packet  \
# Src Port                             0.006619                    0.010090
# Dst Port                            -0.003399                   -0.008985
# Protocol                                  NaN                         NaN
# Timestamp                            0.009746                   -0.000688
# Flow Duration                        0.007762                    0.004774
# Total Fwd Packet                     0.901475                    0.756779
# Total Bwd packets                    1.000000                    0.509115
# Total Length of Fwd Packet           0.509115                    1.000000
# Total Length of Bwd Packet           0.441109                    0.007717
# Fwd Packet Length Max                0.119771                    0.108664
# Fwd Packet Length Min               -0.000786                    0.016787
# Fwd Packet Length Mean               0.047566                    0.091910
# Fwd Packet Length Std                0.089691                    0.073242
# Bwd Packet Length Max                0.073217                    0.022553
# Bwd Packet Length Min                0.010143                   -0.000727
# Bwd Packet Length Mean               0.057293                   -0.000538
# Bwd Packet Length Std                0.052737                    0.005697
# Flow Bytes/s                        -0.000078                    0.000776
# Flow Packets/s                      -0.000885                   -0.000236
# Flow IAT Mean                       -0.023094                   -0.009581
# Flow IAT Std                        -0.009493                   -0.004822
# Flow IAT Max                        -0.012853                   -0.004200
# Flow IAT Min                        -0.023635                   -0.009093
# Fwd IAT Total                        0.007549                    0.004720
# Fwd IAT Mean                        -0.021057                   -0.009441
# Fwd IAT Std                         -0.009023                   -0.004629
# Fwd IAT Max                         -0.012776                   -0.004206
# Fwd IAT Min                         -0.024008                   -0.009214
# Bwd IAT Total                        0.205073                    0.083621
# Bwd IAT Mean                         0.007121                   -0.000641
# Bwd IAT Std                          0.005908                   -0.000067
# Bwd IAT Max                          0.018742                    0.008690
# Bwd IAT Min                          0.000297                   -0.000306
# Fwd PSH Flags                        0.078747                    0.022665
# Bwd PSH Flags                             NaN                         NaN
# Fwd URG Flags                       -0.000116                   -0.000045
# Bwd URG Flags                             NaN                         NaN
# Fwd Header Length                    0.910676                    0.762955
# Bwd Header Length                    0.999931                    0.509298
# Fwd Packets/s                       -0.000871                   -0.000227
# Bwd Packets/s                        0.000392                    0.000091
# Packet Length Min                   -0.000838                    0.009357
# Packet Length Max                    0.123802                    0.074561
# Packet Length Mean                   0.054559                    0.058152
# Packet Length Std                    0.096203                    0.059390
# Packet Length Variance               0.075486                    0.050766
# FIN Flag Count                       0.016002                    0.002264
# SYN Flag Count                       0.027128                    0.006204
# RST Flag Count                      -0.004385                   -0.005476
# PSH Flag Count                       0.898797                    0.392463
# ACK Flag Count                       0.974592                    0.664617
# URG Flag Count                      -0.000161                   -0.000089
# CWR Flag Count                       0.004007                    0.000104
# ECE Flag Count                       0.001437                    0.000038
# Down/Up Ratio                        0.029356                   -0.002202
# Average Packet Size                  0.050461                    0.054401
# Fwd Segment Size Avg                 0.047566                    0.091910
# Bwd Segment Size Avg                 0.057293                   -0.000538
# Fwd Bytes/Bulk Avg                        NaN                         NaN
# Fwd Packet/Bulk Avg                       NaN                         NaN
# Fwd Bulk Rate Avg                         NaN                         NaN
# Bwd Bytes/Bulk Avg                   0.447255                    0.663715
# Bwd Packet/Bulk Avg                  0.773440                    0.541972
# Bwd Bulk Rate Avg                    0.000271                    0.000817
# Subflow Fwd Packets                  0.593419                    0.312303
# Subflow Fwd Bytes                    0.542342                    0.435104
# Subflow Bwd Packets                  0.602856                    0.269149
# Subflow Bwd Bytes                    0.226770                    0.001544
# FWD Init Win Bytes                   0.032921                    0.008260
# Bwd Init Win Bytes                   0.002904                    0.001629
# Fwd Act Data Pkts                    0.814796                    0.804339
# Fwd Seg Size Min                     0.077356                    0.039554
# Active Mean                         -0.009070                   -0.001607
# Active Std                          -0.005721                   -0.001274
# Active Max                          -0.009433                   -0.001675
# Active Min                          -0.007760                   -0.001200
# Idle Mean                           -0.011409                   -0.003631
# Idle Std                            -0.008976                   -0.003072
# Idle Max                            -0.011644                   -0.003816
# Idle Min                            -0.008572                   -0.002563
# Label                               -0.039412                   -0.008537
# Attack Type                          0.005935                    0.001075
#
#                             Total Length of Bwd Packet  Fwd Packet Length Max  \
# Src Port                                     -0.015181               0.090031
# Dst Port                                      0.013538              -0.082516
# Protocol                                           NaN                    NaN
# Timestamp                                    -0.000746              -0.027470
# Flow Duration                                -0.004466              -0.111181
# Total Fwd Packet                              0.220604               0.120204
# Total Bwd packets                             0.441109               0.119771
# Total Length of Fwd Packet                    0.007717               0.108664
# Total Length of Bwd Packet                    1.000000               0.022971
# Fwd Packet Length Max                         0.022971               1.000000
# Fwd Packet Length Min                        -0.000824               0.620377
# Fwd Packet Length Mean                       -0.000236               0.931221
# Fwd Packet Length Std                         0.007026               0.902417
# Bwd Packet Length Max                         0.110568               0.021949
# Bwd Packet Length Min                         0.028524              -0.005585
# Bwd Packet Length Mean                        0.121147               0.002062
# Bwd Packet Length Std                         0.079972               0.023082
# Flow Bytes/s                                  0.000074               0.037561
# Flow Packets/s                               -0.000356               0.001924
# Flow IAT Mean                                -0.010301              -0.085516
# Flow IAT Std                                 -0.005144              -0.034660
# Flow IAT Max                                 -0.004282              -0.055443
# Flow IAT Min                                 -0.009767              -0.085382
# Fwd IAT Total                                -0.004548              -0.112115
# Fwd IAT Mean                                 -0.009891              -0.085573
# Fwd IAT Std                                  -0.004783              -0.033068
# Fwd IAT Max                                  -0.004094              -0.057469
# Fwd IAT Min                                  -0.009551              -0.091176
# Bwd IAT Total                                 0.045008               0.046056
# Bwd IAT Mean                                 -0.000655               0.015623
# Bwd IAT Std                                   0.000156               0.015073
# Bwd IAT Max                                   0.012140               0.026181
# Bwd IAT Min                                  -0.000229               0.009486
# Fwd PSH Flags                                 0.001433               0.223796
# Bwd PSH Flags                                      NaN                    NaN
# Fwd URG Flags                                -0.000048              -0.000451
# Bwd URG Flags                                      NaN                    NaN
# Fwd Header Length                             0.224231               0.128571
# Bwd Header Length                             0.440897               0.119453
# Fwd Packets/s                                -0.000358               0.001842
# Bwd Packets/s                                 0.000292               0.004160
# Packet Length Min                            -0.000348               0.265531
# Packet Length Max                             0.080729               0.688515
# Packet Length Mean                            0.069880               0.720128
# Packet Length Std                             0.086267               0.611074
# Packet Length Variance                        0.087566               0.530518
# FIN Flag Count                                0.019880               0.058007
# SYN Flag Count                                0.018559              -0.000615
# RST Flag Count                                0.004952               0.010503
# PSH Flag Count                                0.099760               0.127837
# ACK Flag Count                                0.329415               0.134201
# URG Flag Count                               -0.000096              -0.000900
# CWR Flag Count                                0.000674               0.003947
# ECE Flag Count                               -0.000010               0.002682
# Down/Up Ratio                                 0.040940              -0.016094
# Average Packet Size                           0.065367               0.730696
# Fwd Segment Size Avg                         -0.000236               0.931221
# Bwd Segment Size Avg                          0.121147               0.002062
# Fwd Bytes/Bulk Avg                                 NaN                    NaN
# Fwd Packet/Bulk Avg                                NaN                    NaN
# Fwd Bulk Rate Avg                                  NaN                    NaN
# Bwd Bytes/Bulk Avg                            0.120688               0.101267
# Bwd Packet/Bulk Avg                           0.110264               0.123145
# Bwd Bulk Rate Avg                             0.000673               0.032727
# Subflow Fwd Packets                           0.041953               0.080676
# Subflow Fwd Bytes                             0.000923               0.083986
# Subflow Bwd Packets                           0.071905               0.079528
# Subflow Bwd Bytes                             0.370895               0.010539
# FWD Init Win Bytes                            0.022385               0.038544
# Bwd Init Win Bytes                           -0.000473               0.002238
# Fwd Act Data Pkts                             0.005574               0.140284
# Fwd Seg Size Min                              0.018173               0.396940
# Active Mean                                  -0.002416              -0.041428
# Active Std                                   -0.000328              -0.030059
# Active Max                                   -0.002383              -0.045117
# Active Min                                   -0.002398              -0.034218
# Idle Mean                                    -0.003401              -0.043202
# Idle Std                                     -0.002815              -0.035697
# Idle Max                                     -0.003621              -0.044680
# Idle Min                                     -0.002339              -0.031767
# Label                                        -0.000711              -0.085368
# Attack Type                                  -0.001883               0.008441
#
#                             ...  Active Mean  Active Std  Active Max  \
# Src Port                    ...     0.068810    0.058164    0.076095
# Dst Port                    ...    -0.160626   -0.168343   -0.194154
# Protocol                    ...          NaN         NaN         NaN
# Timestamp                   ...    -0.130032   -0.092529   -0.139780
# Flow Duration               ...     0.287282    0.258291    0.334846
# Total Fwd Packet            ...     0.047647    0.045305    0.056866
# Total Bwd packets           ...    -0.009070   -0.005721   -0.009433
# Total Length of Fwd Packet  ...    -0.001607   -0.001274   -0.001675
# Total Length of Bwd Packet  ...    -0.002416   -0.000328   -0.002383
# Fwd Packet Length Max       ...    -0.041428   -0.030059   -0.045117
# Fwd Packet Length Min       ...    -0.024300   -0.017923   -0.026642
# Fwd Packet Length Mean      ...    -0.036916   -0.026967   -0.040282
# Fwd Packet Length Std       ...    -0.038876   -0.028287   -0.042367
# Bwd Packet Length Max       ...    -0.042805   -0.031394   -0.046846
# Bwd Packet Length Min       ...    -0.022799   -0.016849   -0.025017
# Bwd Packet Length Mean      ...    -0.038877   -0.028588   -0.042620
# Bwd Packet Length Std       ...    -0.040183   -0.029540   -0.044010
# Flow Bytes/s                ...    -0.002323   -0.001719   -0.002550
# Flow Packets/s              ...    -0.011172   -0.008267   -0.012266
# Flow IAT Mean               ...     0.055157    0.017177    0.049461
# Flow IAT Std                ...     0.070748    0.008420    0.057128
# Flow IAT Max                ...     0.106867    0.037966    0.097562
# Flow IAT Min                ...     0.056998    0.034341    0.057791
# Fwd IAT Total               ...     0.287715    0.258564    0.335299
# Fwd IAT Mean                ...     0.055087    0.018217    0.050026
# Fwd IAT Std                 ...     0.063869    0.005451    0.050481
# Fwd IAT Max                 ...     0.109138    0.039623    0.100041
# Fwd IAT Min                 ...     0.066699    0.041295    0.068284
# Bwd IAT Total               ...    -0.029996   -0.007392   -0.022120
# Bwd IAT Mean                ...    -0.027239   -0.016647   -0.027663
# Bwd IAT Std                 ...    -0.027302   -0.017966   -0.028812
# Bwd IAT Max                 ...    -0.029237   -0.018579   -0.030319
# Bwd IAT Min                 ...    -0.010839   -0.008222   -0.011966
# Fwd PSH Flags               ...    -0.036205   -0.016399   -0.032106
# Bwd PSH Flags               ...          NaN         NaN         NaN
# Fwd URG Flags               ...    -0.001384   -0.001024   -0.001519
# Bwd URG Flags               ...          NaN         NaN         NaN
# Fwd Header Length           ...     0.027160    0.026666    0.032843
# Bwd Header Length           ...    -0.008935   -0.005618   -0.009286
# Fwd Packets/s               ...    -0.010590   -0.007836   -0.011626
# Bwd Packets/s               ...    -0.002788   -0.002063   -0.003061
# Packet Length Min           ...    -0.011081   -0.008199   -0.012165
# Packet Length Max           ...    -0.059066   -0.043230   -0.064561
# Packet Length Mean          ...    -0.051166   -0.037619   -0.056036
# Packet Length Std           ...    -0.056989   -0.041752   -0.062311
# Packet Length Variance      ...    -0.049530   -0.036495   -0.054304
# FIN Flag Count              ...    -0.073750   -0.054613   -0.080976
# SYN Flag Count              ...    -0.174213   -0.129159   -0.191334
# RST Flag Count              ...    -0.244017   -0.180610   -0.267918
# PSH Flag Count              ...    -0.008781   -0.005999   -0.009250
# ACK Flag Count              ...    -0.008086   -0.005173   -0.008402
# URG Flag Count              ...    -0.002761   -0.002043   -0.003031
# CWR Flag Count              ...    -0.000068   -0.000079   -0.000229
# ECE Flag Count              ...    -0.002562   -0.001810   -0.002770
# Down/Up Ratio               ...    -0.070846   -0.050320   -0.076928
# Average Packet Size         ...    -0.051166   -0.037637   -0.056045
# Fwd Segment Size Avg        ...    -0.036916   -0.026967   -0.040282
# Bwd Segment Size Avg        ...    -0.038877   -0.028588   -0.042620
# Fwd Bytes/Bulk Avg          ...          NaN         NaN         NaN
# Fwd Packet/Bulk Avg         ...          NaN         NaN         NaN
# Fwd Bulk Rate Avg           ...          NaN         NaN         NaN
# Bwd Bytes/Bulk Avg          ...    -0.005937   -0.004468   -0.006543
# Bwd Packet/Bulk Avg         ...    -0.006754   -0.005031   -0.007426
# Bwd Bulk Rate Avg           ...    -0.002348   -0.001738   -0.002578
# Subflow Fwd Packets         ...    -0.001213   -0.000900   -0.001332
# Subflow Fwd Bytes           ...    -0.002653   -0.002019   -0.002912
# Subflow Bwd Packets         ...    -0.004151   -0.002988   -0.004519
# Subflow Bwd Bytes           ...    -0.001464   -0.000632   -0.001523
# FWD Init Win Bytes          ...    -0.092603   -0.068403   -0.101585
# Bwd Init Win Bytes          ...    -0.051450   -0.037516   -0.056155
# Fwd Act Data Pkts           ...    -0.005528   -0.003745   -0.005717
# Fwd Seg Size Min            ...    -0.096903   -0.067000   -0.102851
# Active Mean                 ...     1.000000    0.339875    0.941227
# Active Std                  ...     0.339875    1.000000    0.614731
# Active Max                  ...     0.941227    0.614731    1.000000
# Active Min                  ...     0.956683    0.058882    0.815290
# Idle Mean                   ...     0.157784    0.068218    0.152258
# Idle Std                    ...     0.076627    0.025940    0.067611
# Idle Max                    ...     0.135850    0.061028    0.130158
# Idle Min                    ...     0.154939    0.072628    0.153062
# Label                       ...     0.028670    0.011458    0.024027
# Attack Type                 ...    -0.226154   -0.168758   -0.249353
#
#                               Active Min  Idle Mean  Idle Std  Idle Max  \
# Src Port                    5.156977e-02   0.138516  0.094362  0.141558
# Dst Port                   -1.154868e-01  -0.330297 -0.204830 -0.311831
# Protocol                             NaN        NaN       NaN       NaN
# Timestamp                  -1.082811e-01  -0.101572 -0.115079 -0.118649
# Flow Duration               2.223243e-01   0.383921  0.281856  0.387700
# Total Fwd Packet            3.600891e-02  -0.011962 -0.010718 -0.013463
# Total Bwd packets          -7.759658e-03  -0.011409 -0.008976 -0.011644
# Total Length of Fwd Packet -1.199901e-03  -0.003631 -0.003072 -0.003816
# Total Length of Bwd Packet -2.398476e-03  -0.003401 -0.002815 -0.003621
# Fwd Packet Length Max      -3.421800e-02  -0.043202 -0.035697 -0.044680
# Fwd Packet Length Min      -1.997999e-02  -0.030350 -0.021266 -0.029720
# Fwd Packet Length Mean     -3.044042e-02  -0.047055 -0.032355 -0.045804
# Fwd Packet Length Std      -3.209112e-02  -0.038362 -0.033380 -0.040406
# Bwd Packet Length Max      -3.523416e-02  -0.055592 -0.037276 -0.053744
# Bwd Packet Length Min      -1.873485e-02  -0.027840 -0.020165 -0.027527
# Bwd Packet Length Mean     -3.198535e-02  -0.052428 -0.034180 -0.050226
# Bwd Packet Length Std      -3.305883e-02  -0.052657 -0.034796 -0.050696
# Flow Bytes/s               -1.908120e-03  -0.003513 -0.002059 -0.003264
# Flow Packets/s             -9.176502e-03  -0.016897 -0.009901 -0.015700
# Flow IAT Mean               5.383827e-02   0.674430  0.439654  0.665399
# Flow IAT Std                7.451755e-02   0.859313  0.822945  0.962537
# Flow IAT Max                1.037656e-01   0.901711  0.828323  0.992351
# Flow IAT Min                4.946980e-02   0.369984  0.121173  0.316683
# Fwd IAT Total               2.226951e-01   0.378856  0.281632  0.384215
# Fwd IAT Mean                5.337867e-02   0.702100  0.436345  0.682405
# Fwd IAT Std                 6.808822e-02   0.859321  0.777923  0.941737
# Fwd IAT Max                 1.056425e-01   0.892131  0.830526  0.986890
# Fwd IAT Min                 5.751542e-02   0.358232  0.132735  0.314223
# Bwd IAT Total              -3.048180e-02   0.156216 -0.024828  0.094441
# Bwd IAT Mean               -2.369126e-02   0.294621 -0.019771  0.190341
# Bwd IAT Std                -2.322141e-02   0.294543 -0.018845  0.190686
# Bwd IAT Max                -2.512270e-02   0.327593 -0.019331  0.212860
# Bwd IAT Min                -8.834120e-03   0.140520 -0.008639  0.091346
# Fwd PSH Flags              -3.387098e-02   0.148459 -0.031791  0.086327
# Bwd PSH Flags                        NaN        NaN       NaN       NaN
# Fwd URG Flags              -1.136266e-03  -0.001494 -0.001227 -0.001539
# Bwd URG Flags                        NaN        NaN       NaN       NaN
# Fwd Header Length           2.027205e-02  -0.011017 -0.009689 -0.012123
# Bwd Header Length          -7.648828e-03  -0.011169 -0.008856 -0.011431
# Fwd Packets/s              -8.698267e-03  -0.016017 -0.009385 -0.014882
# Bwd Packets/s              -2.290042e-03  -0.004215 -0.002471 -0.003916
# Packet Length Min          -9.101929e-03  -0.003725 -0.009749 -0.006714
# Packet Length Max          -4.866642e-02  -0.074343 -0.051475 -0.072543
# Packet Length Mean         -4.210342e-02  -0.070167 -0.045064 -0.066916
# Packet Length Std          -4.694392e-02  -0.073684 -0.049775 -0.071367
# Packet Length Variance     -4.071909e-02  -0.068262 -0.043595 -0.065006
# FIN Flag Count             -6.055724e-02  -0.080864 -0.064385 -0.082604
# SYN Flag Count             -1.430122e-01  -0.227051 -0.153604 -0.219951
# RST Flag Count             -2.004195e-01  -0.353183 -0.215776 -0.331997
# PSH Flag Count             -7.412361e-03  -0.010571 -0.008040 -0.010624
# ACK Flag Count             -6.884047e-03  -0.010061 -0.008224 -0.010404
# URG Flag Count             -2.267293e-03  -0.003736 -0.002447 -0.003582
# CWR Flag Count             -1.928398e-07  -0.001998 -0.001858 -0.002177
# ECE Flag Count             -2.117229e-03  -0.002718 -0.002406 -0.002890
# Down/Up Ratio              -5.890619e-02  -0.090015 -0.061272 -0.087470
# Average Packet Size        -4.209744e-02  -0.069625 -0.045063 -0.066549
# Fwd Segment Size Avg       -3.044042e-02  -0.047055 -0.032355 -0.045804
# Bwd Segment Size Avg       -3.198535e-02  -0.052428 -0.034180 -0.050226
# Fwd Bytes/Bulk Avg                   NaN        NaN       NaN       NaN
# Fwd Packet/Bulk Avg                  NaN        NaN       NaN       NaN
# Fwd Bulk Rate Avg                    NaN        NaN       NaN       NaN
# Bwd Bytes/Bulk Avg         -4.838746e-03  -0.008580 -0.005563 -0.008210
# Bwd Packet/Bulk Avg        -5.530614e-03  -0.009927 -0.006130 -0.009362
# Bwd Bulk Rate Avg          -1.927984e-03  -0.003495 -0.002082 -0.003262
# Subflow Fwd Packets        -9.890486e-04   0.000412 -0.001175 -0.000233
# Subflow Fwd Bytes          -2.143279e-03  -0.003721 -0.002625 -0.003658
# Subflow Bwd Packets        -3.434182e-03  -0.003280 -0.003730 -0.003836
# Subflow Bwd Bytes          -1.326458e-03  -0.001548 -0.001548 -0.001748
# FWD Init Win Bytes         -7.610426e-02  -0.125502 -0.081210 -0.119939
# Bwd Init Win Bytes         -4.245435e-02  -0.058284 -0.043673 -0.058265
# Fwd Act Data Pkts          -4.632557e-03  -0.007853 -0.005952 -0.007901
# Fwd Seg Size Min           -8.147559e-02  -0.004390 -0.085130 -0.040023
# Active Mean                 9.566827e-01   0.157784  0.076627  0.135850
# Active Std                  5.888156e-02   0.068218  0.025940  0.061028
# Active Max                  8.152897e-01   0.152258  0.067611  0.130158
# Active Min                  1.000000e+00   0.147042  0.075927  0.126944
# Idle Mean                   1.470425e-01   1.000000  0.561240  0.916477
# Idle Std                    7.592701e-02   0.561240  1.000000  0.825193
# Idle Max                    1.269437e-01   0.916477  0.825193  1.000000
# Idle Min                    1.414323e-01   0.914732  0.199313  0.702126
# Label                       2.739453e-02  -0.189565  0.023452 -0.117693
# Attack Type                -1.852086e-01  -0.361925 -0.200324 -0.331195
#
#                             Idle Min     Label  Attack Type
# Src Port                    0.117423 -0.037207    -0.232306
# Dst Port                   -0.281328  0.054486     0.673504
# Protocol                         NaN       NaN          NaN
# Timestamp                  -0.056302 -0.375797     0.666840
# Flow Duration               0.296685 -0.061755    -0.702953
# Total Fwd Packet           -0.008028 -0.021827    -0.096840
# Total Bwd packets          -0.008572 -0.039412     0.005935
# Total Length of Fwd Packet -0.002563 -0.008537     0.001075
# Total Length of Bwd Packet -0.002339 -0.000711    -0.001883
# Fwd Packet Length Max      -0.031767 -0.085368     0.008441
# Fwd Packet Length Min      -0.024475 -0.010188     0.013921
# Fwd Packet Length Mean     -0.038276 -0.031696     0.017258
# Fwd Packet Length Std      -0.027225 -0.091934     0.005628
# Bwd Packet Length Max      -0.045855 -0.014340     0.024125
# Bwd Packet Length Min      -0.021999 -0.008314     0.013556
# Bwd Packet Length Mean     -0.043708 -0.005406     0.024439
# Bwd Packet Length Std      -0.043752 -0.013215     0.022936
# Flow Bytes/s               -0.003063  0.000300     0.001484
# Flow Packets/s             -0.014733 -0.016943     0.011078
# Flow IAT Mean               0.554088 -0.097250    -0.514150
# Flow IAT Std                0.638364 -0.163032    -0.291842
# Flow IAT Max                0.685289 -0.116800    -0.390271
# Flow IAT Min                0.374288 -0.034760    -0.468024
# Fwd IAT Total               0.290887 -0.043168    -0.699774
# Fwd IAT Mean                0.590123 -0.099150    -0.528413
# Fwd IAT Std                 0.661191 -0.184119    -0.280884
# Fwd IAT Max                 0.672567 -0.088625    -0.391746
# Fwd IAT Min                 0.353103  0.055614    -0.497302
# Bwd IAT Total               0.202757 -0.738956    -0.163736
# Bwd IAT Mean                0.369400 -0.529650    -0.112803
# Bwd IAT Std                 0.369253 -0.462531    -0.095953
# Bwd IAT Max                 0.409500 -0.540964    -0.115514
# Bwd IAT Min                 0.175872 -0.226915    -0.049566
# Fwd PSH Flags               0.198442 -0.585967    -0.125369
# Bwd PSH Flags                    NaN       NaN          NaN
# Fwd URG Flags              -0.001096  0.000379     0.005628
# Bwd URG Flags                    NaN       NaN          NaN
# Fwd Header Length          -0.007553 -0.028086    -0.060393
# Bwd Header Length          -0.008343 -0.039156     0.004852
# Fwd Packets/s              -0.013965 -0.016996     0.010584
# Bwd Packets/s              -0.003674 -0.001823     0.003252
# Packet Length Min           0.001216 -0.030360     0.000406
# Packet Length Max          -0.060341 -0.055649     0.027182
# Packet Length Mean         -0.058893 -0.017490     0.030272
# Packet Length Std          -0.060516 -0.049731     0.026821
# Packet Length Variance     -0.057447 -0.029356     0.025612
# FIN Flag Count             -0.060436 -0.035788     0.081545
# SYN Flag Count             -0.185750  0.025931     0.607449
# RST Flag Count             -0.302672  0.058695     0.651427
# PSH Flag Count             -0.008151 -0.040075     0.003462
# ACK Flag Count             -0.007375 -0.040034     0.003140
# URG Flag Count             -0.003106  0.000756     0.011224
# CWR Flag Count             -0.001358 -0.001927    -0.000716
# ECE Flag Count             -0.001949 -0.003738     0.002468
# Down/Up Ratio              -0.074229 -0.049819     0.228597
# Average Packet Size        -0.058233 -0.018237     0.030134
# Fwd Segment Size Avg       -0.038276 -0.031696     0.017258
# Bwd Segment Size Avg       -0.043708 -0.005406     0.024439
# Fwd Bytes/Bulk Avg               NaN       NaN          NaN
# Fwd Packet/Bulk Avg              NaN       NaN          NaN
# Fwd Bulk Rate Avg                NaN       NaN          NaN
# Bwd Bytes/Bulk Avg         -0.007152 -0.009558     0.004853
# Bwd Packet/Bulk Avg        -0.008466 -0.005206     0.009298
# Bwd Bulk Rate Avg          -0.003027 -0.000086     0.001590
# Subflow Fwd Packets         0.001204 -0.002812    -0.002084
# Subflow Fwd Bytes          -0.002965 -0.002780     0.005711
# Subflow Bwd Packets        -0.001791 -0.003534     0.007357
# Subflow Bwd Bytes          -0.000932 -0.004087    -0.000298
# FWD Init Win Bytes         -0.105107 -0.020065     0.112009
# Bwd Init Win Bytes         -0.045562 -0.022249     0.104936
# Fwd Act Data Pkts          -0.006037 -0.035396     0.000904
# Fwd Seg Size Min            0.044387 -0.314087     0.038918
# Active Mean                 0.154939  0.028670    -0.226154
# Active Std                  0.072628  0.011458    -0.168758
# Active Max                  0.153062  0.024027    -0.249353
# Active Min                  0.141432  0.027395    -0.185209
# Idle Mean                   0.914732 -0.189565    -0.361925
# Idle Std                    0.199313  0.023452    -0.200324
# Idle Max                    0.702126 -0.117693    -0.331195
# Idle Min                    1.000000 -0.242716    -0.322174
# Label                      -0.242716  1.000000     0.208886
# Attack Type                -0.322174  0.208886     1.000000
#
# [82 rows x 82 columns]
